# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df= pd.read_csv("/workspaces/projects/Uber_Fare/uber.csv")
df.head(10).T
# Out:
#                                              0                            1  \
# Unnamed: 0                            24238194                     27835199
# key                2015-05-07 19:52:06.0000003  2009-07-17 20:04:56.0000002
# fare_amount                                7.5                          7.7
# pickup_datetime        2015-05-07 19:52:06 UTC      2009-07-17 20:04:56 UTC
# pickup_longitude                    -73.999817                   -73.994355
# pickup_latitude                      40.738354                    40.728225
# dropoff_longitude                   -73.999512                    -73.99471
# dropoff_latitude                     40.723217                    40.750325
# passenger_count                              1                            1
#
#                                               2                            3  \
# Unnamed: 0                             44984355                     25894730
# key                2009-08-24 21:45:00.00000061  2009-06-26 08:22:21.0000001
# fare_amount                                12.9                          5.3
# pickup_datetime         2009-08-24 21:45:00 UTC      2009-06-26 08:22:21 UTC
# pickup_longitude                     -74.005043                   -73.976124
# pickup_latitude                        40.74077                    40.790844
# dropoff_longitude                    -73.962565                   -73.965316
# dropoff_latitude                      40.772647                    40.803349
# passenger_count                               1                            3
#
#                                                4                            5  \
# Unnamed: 0                              17610152                     44470845
# key                2014-08-28 17:47:00.000000188  2011-02-12 02:27:09.0000006
# fare_amount                                 16.0                          4.9
# pickup_datetime          2014-08-28 17:47:00 UTC      2011-02-12 02:27:09 UTC
# pickup_longitude                      -73.925023                   -73.969019
# pickup_latitude                        40.744085                     40.75591
# dropoff_longitude                     -73.973082                   -73.969019
# dropoff_latitude                       40.761247                     40.75591
# passenger_count                                5                            1
#
#                                              6                             7  \
# Unnamed: 0                            48725865                      44195482
# key                2014-10-12 07:04:00.0000002  2012-12-11 13:52:00.00000029
# fare_amount                               24.5                           2.5
# pickup_datetime        2014-10-12 07:04:00 UTC       2012-12-11 13:52:00 UTC
# pickup_longitude                    -73.961447                           0.0
# pickup_latitude                      40.693965                           0.0
# dropoff_longitude                   -73.871195                           0.0
# dropoff_latitude                     40.774297                           0.0
# passenger_count                              5                             1
#
#                                               8                              9
# Unnamed: 0                             15822268                       50611056
# key                2012-02-17 09:32:00.00000043  2012-03-29 19:06:00.000000273
# fare_amount                                 9.7                           12.5
# pickup_datetime         2012-02-17 09:32:00 UTC        2012-03-29 19:06:00 UTC
# pickup_longitude                     -73.975187                     -74.001065
# pickup_latitude                       40.745767                      40.741787
# dropoff_longitude                     -74.00272                      -73.96304
# dropoff_latitude                      40.743537                      40.775012
# passenger_count                               1                              1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 9 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Unnamed: 0         200000 non-null  int64
#  1   key                200000 non-null  object
#  2   fare_amount        200000 non-null  float64
#  3   pickup_datetime    200000 non-null  object
#  4   pickup_longitude   200000 non-null  float64
#  5   pickup_latitude    200000 non-null  float64
#  6   dropoff_longitude  199999 non-null  float64
#  7   dropoff_latitude   199999 non-null  float64
#  8   passenger_count    200000 non-null  int64
# dtypes: float64(5), int64(2), object(2)
# memory usage: 13.7+ MB

# %%
df = df.drop(['Unnamed: 0','key'],axis=1)
df.dropna(axis=0,inplace=True)

# %%
df['pickup_datetime'] = pd.to_datetime(df['pickup_datetime'])
df['Year'] = df['pickup_datetime'].apply(lambda time: time.year)
df['Month'] = df['pickup_datetime'].apply(lambda time: time.month)
df['Day'] = df['pickup_datetime'].apply(lambda time: time.day)
df['Day of Week'] = df['pickup_datetime'].apply(lambda time: time.dayofweek)
df['Day of Week_num'] = df['pickup_datetime'].apply(lambda time: time.dayofweek)
df['Hour'] = df['pickup_datetime'].apply(lambda time: time.hour)
day_map = {0:'Mon',1:'Tue',2:'Wed',3:'Thu',4:'Fri',5:'Sat',6:'Sun'}
df['Day of Week'] = df['Day of Week'].map(day_map)

# %%
df.describe().T
# Out:
#                       count         mean        std          min          25%  \
# fare_amount        199999.0    11.359892   9.901760   -52.000000     6.000000
# pickup_longitude   199999.0   -72.527631  11.437815 -1340.648410   -73.992065
# pickup_latitude    199999.0    39.935881   7.720558   -74.015515    40.734796
# dropoff_longitude  199999.0   -72.525292  13.117408 -3356.666300   -73.991407
# dropoff_latitude   199999.0    39.923890   6.794829  -881.985513    40.733823
# passenger_count    199999.0     1.684543   1.385995     0.000000     1.000000
# Year               199999.0  2011.742434   1.856400  2009.000000  2010.000000
# Month              199999.0     6.281791   3.438933     1.000000     3.000000
# Day                199999.0    15.704739   8.687377     1.000000     8.000000
# Day of Week_num    199999.0     3.048435   1.946946     0.000000     1.000000
# Hour               199999.0    13.491387   6.515505     0.000000     9.000000
#
#                            50%          75%          max
# fare_amount           8.500000    12.500000   499.000000
# pickup_longitude    -73.981823   -73.967154    57.418457
# pickup_latitude      40.752592    40.767158  1644.421482
# dropoff_longitude   -73.980093   -73.963658  1153.572603
# dropoff_latitude     40.753042    40.768001   872.697628
# passenger_count       1.000000     2.000000   208.000000
# Year               2012.000000  2013.000000  2015.000000
# Month                 6.000000     9.000000    12.000000
# Day                  16.000000    23.000000    31.000000
# Day of Week_num       3.000000     5.000000     6.000000
# Hour                 14.000000    19.000000    23.000000

# %%
drop1 = df[(df['pickup_latitude'] > 90) | (df['pickup_latitude'] < -90)].index
drop2 = df[(df['dropoff_latitude'] > 90) | (df['dropoff_latitude'] < -90)].index
drop3 = df[(df['pickup_longitude'] > 180) | (df['pickup_longitude'] < -180)].index
drop4 = df[(df['dropoff_longitude'] > 180) | (df['dropoff_longitude'] < -180)].index

indices_to_drop = drop1.union(drop2).union(drop3).union(drop4)

df.drop(indices_to_drop, axis=0, inplace=True)
df.shape
# Out:
# (199987, 13)

# %%
drop5=df[df['fare_amount']<0].index
df.drop(drop5,axis=0,inplace=True)

# %%
df.describe()
# Out:
#          fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# count  199970.000000     199970.000000    199970.000000      199970.000000
# mean       11.362259        -72.501661        39.917866         -72.511852
# std         9.897210         10.450391         6.130667          10.411364
# min         0.000000        -93.824668       -74.015515         -75.458979
# 25%         6.000000        -73.992065        40.734793         -73.991407
# 50%         8.500000        -73.981822        40.752592         -73.980092
# 75%        12.500000        -73.967154        40.767157         -73.963657
# max       499.000000         40.808425        48.018760          40.831932
#
#        dropoff_latitude  passenger_count           Year          Month  \
# count     199970.000000    199970.000000  199970.000000  199970.000000
# mean          39.922164         1.684503    2011.742386       6.282037
# std            6.117273         1.385981       1.856355       3.438972
# min          -74.015750         0.000000    2009.000000       1.000000
# 25%           40.733824         1.000000    2010.000000       3.000000
# 50%           40.753042         1.000000    2012.000000       6.000000
# 75%           40.768001         2.000000    2013.000000       9.000000
# max           45.031598       208.000000    2015.000000      12.000000
#
#                  Day  Day of Week_num           Hour
# count  199970.000000    199970.000000  199970.000000
# mean       15.705056         3.048422      13.491504
# std         8.687549         1.946984       6.515409
# min         1.000000         0.000000       0.000000
# 25%         8.000000         1.000000       9.000000
# 50%        16.000000         3.000000      14.000000
# 75%        23.000000         5.000000      19.000000
# max        31.000000         6.000000      23.000000

# %%
df['pickup_coordinates'] = list(zip(df['pickup_latitude'], df['pickup_longitude']))
df['dropoff_coordinates'] = list(zip(df['dropoff_latitude'], df['dropoff_longitude']))

# %%
from geopy.distance import geodesic
geodesic(df['pickup_coordinates'][0],df['dropoff_coordinates'][0]).kilometers
# Out:
# 1.6811107421764293

# %%
def calculate_distance(row):
    return geodesic(row['pickup_coordinates'], row['dropoff_coordinates']).kilometers
df['distance']=df.apply(calculate_distance,axis=1)
df.head().T
# Out:
#                                                            0  \
# fare_amount                                              7.5
# pickup_datetime                    2015-05-07 19:52:06+00:00
# pickup_longitude                                  -73.999817
# pickup_latitude                                    40.738354
# dropoff_longitude                                 -73.999512
# dropoff_latitude                                   40.723217
# passenger_count                                            1
# Year                                                    2015
# Month                                                      5
# Day                                                        7
# Day of Week                                              Thu
# Day of Week_num                                            3
# Hour                                                      19
# pickup_coordinates   (40.73835372924805, -73.99981689453125)
# dropoff_coordinates     (40.72321701049805, -73.99951171875)
# distance                                            1.681111
#
#                                              1                          2  \
# fare_amount                                7.7                       12.9
# pickup_datetime      2009-07-17 20:04:56+00:00  2009-08-24 21:45:00+00:00
# pickup_longitude                    -73.994355                 -74.005043
# pickup_latitude                      40.728225                   40.74077
# dropoff_longitude                    -73.99471                 -73.962565
# dropoff_latitude                     40.750325                  40.772647
# passenger_count                              1                          1
# Year                                      2009                       2009
# Month                                        7                          8
# Day                                         17                         24
# Day of Week                                Fri                        Mon
# Day of Week_num                              4                          0
# Hour                                        20                         21
# pickup_coordinates     (40.728225, -73.994355)     (40.74077, -74.005043)
# dropoff_coordinates     (40.750325, -73.99471)    (40.772647, -73.962565)
# distance                              2.454363                   5.039603
#
#                                              3  \
# fare_amount                                5.3
# pickup_datetime      2009-06-26 08:22:21+00:00
# pickup_longitude                    -73.976124
# pickup_latitude                      40.790844
# dropoff_longitude                   -73.965316
# dropoff_latitude                     40.803349
# passenger_count                              3
# Year                                      2009
# Month                                        6
# Day                                         26
# Day of Week                                Fri
# Day of Week_num                              4
# Hour                                         8
# pickup_coordinates     (40.790844, -73.976124)
# dropoff_coordinates    (40.803349, -73.965316)
# distance                              1.661442
#
#                                                    4
# fare_amount                                     16.0
# pickup_datetime            2014-08-28 17:47:00+00:00
# pickup_longitude                          -73.925023
# pickup_latitude                            40.744085
# dropoff_longitude                         -73.973082
# dropoff_latitude                           40.761247
# passenger_count                                    5
# Year                                            2014
# Month                                              8
# Day                                               28
# Day of Week                                      Thu
# Day of Week_num                                    3
# Hour                                              17
# pickup_coordinates           (40.744085, -73.925023)
# dropoff_coordinates  (40.761247, -73.97308199999999)
# distance                                     4.48373

# %%
import seaborn as sns
fare_pivot = df.pivot_table(values='fare_amount', index='Day of Week', columns='Hour', aggfunc='mean')
plt.figure(figsize=(16, 5))
sns.heatmap(fare_pivot)
plt.title('Average Fare Amount by Day and Hour')
plt.show()

# %%
piv2= df.pivot_table(values='fare_amount',index='Day of Week',columns='Hour',aggfunc='count')
plt.figure(figsize=(16, 5))
sns.heatmap(piv2)
plt.title('Count of Trips by Day and Hour')
plt.show()

# %%
num = df.select_dtypes(include=['int64','float64'])

# %%
num.corr().style.background_gradient(cmap='BuGn')
# Out:
# <style type="text/css">
# #T_be486_row0_col0, #T_be486_row1_col1, #T_be486_row2_col2, #T_be486_row3_col3, #T_be486_row4_col4, #T_be486_row5_col5, #T_be486_row6_col6, #T_be486_row7_col7, #T_be486_row8_col8, #T_be486_row9_col9, #T_be486_row10_col10, #T_be486_row11_col11 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_be486_row0_col1, #T_be486_row0_col3, #T_be486_row6_col3 {
#   background-color: #65c2a3;
#   color: #000000;
# }
# #T_be486_row0_col2, #T_be486_row0_col4, #T_be486_row6_col2, #T_be486_row6_col4, #T_be486_row8_col2, #T_be486_row8_col4 {
#   background-color: #6ac4a7;
#   color: #000000;
# }
# #T_be486_row0_col5, #T_be486_row10_col5, #T_be486_row11_col8 {
#   background-color: #f5fbfd;
#   color: #000000;
# }
# #T_be486_row0_col6 {
#   background-color: #d4efec;
#   color: #000000;
# }
# #T_be486_row0_col7, #T_be486_row5_col11, #T_be486_row7_col11, #T_be486_row8_col11, #T_be486_row10_col11, #T_be486_row11_col6 {
#   background-color: #e5f5f9;
#   color: #000000;
# }
# #T_be486_row0_col8, #T_be486_row4_col11 {
#   background-color: #f5fbfc;
#   color: #000000;
# }
# #T_be486_row0_col9, #T_be486_row1_col9, #T_be486_row3_col9, #T_be486_row6_col9, #T_be486_row8_col7, #T_be486_row8_col9, #T_be486_row8_col10 {
#   background-color: #ebf7fa;
#   color: #000000;
# }
# #T_be486_row0_col10 {
#   background-color: #eff9fb;
#   color: #000000;
# }
# #T_be486_row0_col11, #T_be486_row6_col11 {
#   background-color: #e1f4f6;
#   color: #000000;
# }
# #T_be486_row1_col0, #T_be486_row3_col0, #T_be486_row9_col5 {
#   background-color: #f2fafc;
#   color: #000000;
# }
# #T_be486_row1_col2, #T_be486_row1_col5, #T_be486_row2_col1, #T_be486_row2_col5, #T_be486_row2_col11, #T_be486_row3_col4, #T_be486_row3_col5, #T_be486_row4_col3, #T_be486_row4_col5, #T_be486_row6_col7, #T_be486_row7_col6, #T_be486_row7_col8, #T_be486_row9_col10, #T_be486_row10_col0, #T_be486_row10_col9, #T_be486_row11_col5 {
#   background-color: #f7fcfd;
#   color: #000000;
# }
# #T_be486_row1_col3, #T_be486_row3_col1 {
#   background-color: #004c1e;
#   color: #f1f1f1;
# }
# #T_be486_row1_col4, #T_be486_row1_col8, #T_be486_row2_col3, #T_be486_row3_col2, #T_be486_row3_col8, #T_be486_row4_col1, #T_be486_row5_col8, #T_be486_row8_col0, #T_be486_row9_col8, #T_be486_row10_col8 {
#   background-color: #f4fbfc;
#   color: #000000;
# }
# #T_be486_row1_col6, #T_be486_row3_col6, #T_be486_row5_col7, #T_be486_row5_col9 {
#   background-color: #e7f6f9;
#   color: #000000;
# }
# #T_be486_row1_col7, #T_be486_row9_col7, #T_be486_row10_col7 {
#   background-color: #e9f7fa;
#   color: #000000;
# }
# #T_be486_row1_col10, #T_be486_row2_col10, #T_be486_row3_col10, #T_be486_row4_col10, #T_be486_row6_col10, #T_be486_row11_col10 {
#   background-color: #ecf8fa;
#   color: #000000;
# }
# #T_be486_row1_col11 {
#   background-color: #c5e9e2;
#   color: #000000;
# }
# #T_be486_row2_col0, #T_be486_row2_col8, #T_be486_row4_col0, #T_be486_row4_col8, #T_be486_row6_col5, #T_be486_row6_col8, #T_be486_row7_col5, #T_be486_row8_col5 {
#   background-color: #f6fcfd;
#   color: #000000;
# }
# #T_be486_row2_col4, #T_be486_row4_col2 {
#   background-color: #004a1e;
#   color: #f1f1f1;
# }
# #T_be486_row2_col6, #T_be486_row4_col6, #T_be486_row5_col10, #T_be486_row8_col6 {
#   background-color: #eaf7fa;
#   color: #000000;
# }
# #T_be486_row2_col7, #T_be486_row3_col7, #T_be486_row4_col7, #T_be486_row5_col6, #T_be486_row9_col6, #T_be486_row10_col6, #T_be486_row11_col7 {
#   background-color: #e8f6fa;
#   color: #000000;
# }
# #T_be486_row2_col9, #T_be486_row4_col9, #T_be486_row7_col10, #T_be486_row11_col9 {
#   background-color: #ecf8fb;
#   color: #000000;
# }
# #T_be486_row3_col11 {
#   background-color: #cdece6;
#   color: #000000;
# }
# #T_be486_row5_col0, #T_be486_row9_col0 {
#   background-color: #f3fafc;
#   color: #000000;
# }
# #T_be486_row5_col1, #T_be486_row5_col2, #T_be486_row5_col3, #T_be486_row5_col4, #T_be486_row7_col1, #T_be486_row7_col3, #T_be486_row9_col1, #T_be486_row9_col2, #T_be486_row9_col3, #T_be486_row9_col4, #T_be486_row10_col1, #T_be486_row10_col2, #T_be486_row10_col3, #T_be486_row10_col4 {
#   background-color: #68c3a6;
#   color: #000000;
# }
# #T_be486_row6_col0 {
#   background-color: #e3f4f7;
#   color: #000000;
# }
# #T_be486_row6_col1, #T_be486_row7_col2, #T_be486_row7_col4, #T_be486_row8_col1, #T_be486_row8_col3 {
#   background-color: #67c2a5;
#   color: #000000;
# }
# #T_be486_row7_col0, #T_be486_row11_col0 {
#   background-color: #f1fafc;
#   color: #000000;
# }
# #T_be486_row7_col9 {
#   background-color: #edf8fb;
#   color: #000000;
# }
# #T_be486_row9_col11 {
#   background-color: #e6f5f9;
#   color: #000000;
# }
# #T_be486_row11_col1 {
#   background-color: #4fb688;
#   color: #f1f1f1;
# }
# #T_be486_row11_col2 {
#   background-color: #85cfbb;
#   color: #000000;
# }
# #T_be486_row11_col3 {
#   background-color: #53b88c;
#   color: #f1f1f1;
# }
# #T_be486_row11_col4 {
#   background-color: #82ceb8;
#   color: #000000;
# }
# </style>
# <table id="T_be486">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_be486_level0_col0" class="col_heading level0 col0" >fare_amount</th>
#       <th id="T_be486_level0_col1" class="col_heading level0 col1" >pickup_longitude</th>
#       <th id="T_be486_level0_col2" class="col_heading level0 col2" >pickup_latitude</th>
#       <th id="T_be486_level0_col3" class="col_heading level0 col3" >dropoff_longitude</th>
#       <th id="T_be486_level0_col4" class="col_heading level0 col4" >dropoff_latitude</th>
#       <th id="T_be486_level0_col5" class="col_heading level0 col5" >passenger_count</th>
#       <th id="T_be486_level0_col6" class="col_heading level0 col6" >Year</th>
#       <th id="T_be486_level0_col7" class="col_heading level0 col7" >Month</th>
#       <th id="T_be486_level0_col8" class="col_heading level0 col8" >Day</th>
#       <th id="T_be486_level0_col9" class="col_heading level0 col9" >Day of Week_num</th>
#       <th id="T_be486_level0_col10" class="col_heading level0 col10" >Hour</th>
#       <th id="T_be486_level0_col11" class="col_heading level0 col11" >distance</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_be486_level0_row0" class="row_heading level0 row0" >fare_amount</th>
#       <td id="T_be486_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_be486_row0_col1" class="data row0 col1" >0.011608</td>
#       <td id="T_be486_row0_col2" class="data row0 col2" >-0.011536</td>
#       <td id="T_be486_row0_col3" class="data row0 col3" >0.012071</td>
#       <td id="T_be486_row0_col4" class="data row0 col4" >-0.012446</td>
#       <td id="T_be486_row0_col5" class="data row0 col5" >0.010420</td>
#       <td id="T_be486_row0_col6" class="data row0 col6" >0.118495</td>
#       <td id="T_be486_row0_col7" class="data row0 col7" >0.023577</td>
#       <td id="T_be486_row0_col8" class="data row0 col8" >0.001360</td>
#       <td id="T_be486_row0_col9" class="data row0 col9" >0.007396</td>
#       <td id="T_be486_row0_col10" class="data row0 col10" >-0.021457</td>
#       <td id="T_be486_row0_col11" class="data row0 col11" >0.025492</td>
#     </tr>
#     <tr>
#       <th id="T_be486_level0_row1" class="row_heading level0 row1" >pickup_longitude</th>
#       <td id="T_be486_row1_col0" class="data row1 col0" >0.011608</td>
#       <td id="T_be486_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_be486_row1_col2" class="data row1 col2" >-0.979048</td>
#       <td id="T_be486_row1_col3" class="data row1 col3" >0.949818</td>
#       <td id="T_be486_row1_col4" class="data row1 col4" >-0.936746</td>
#       <td id="T_be486_row1_col5" class="data row1 col5" >-0.000753</td>
#       <td id="T_be486_row1_col6" class="data row1 col6" >0.009744</td>
#       <td id="T_be486_row1_col7" class="data row1 col7" >-0.003584</td>
#       <td id="T_be486_row1_col8" class="data row1 col8" >0.005362</td>
#       <td id="T_be486_row1_col9" class="data row1 col9" >0.002309</td>
#       <td id="T_be486_row1_col10" class="data row1 col10" >0.001393</td>
#       <td id="T_be486_row1_col11" class="data row1 col11" >0.163780</td>
#     </tr>
#     <tr>
#       <th id="T_be486_level0_row2" class="row_heading level0 row2" >pickup_latitude</th>
#       <td id="T_be486_row2_col0" class="data row2 col0" >-0.011536</td>
#       <td id="T_be486_row2_col1" class="data row2 c

# %%
fig, axes = plt.subplots(6, 2, figsize=(15, 10))
cols = num.columns
axes=axes.flatten()
for i in range(len(cols)):
    axes[i].boxplot(num.iloc[:,i])
    axes[i].set_title(num.columns[i])
plt.tight_layout()
plt.show()

# %%
df.drop(['pickup_coordinates','dropoff_coordinates'],axis=1,inplace=True)
df
# Out:
#         fare_amount           pickup_datetime  pickup_longitude  \
# 0               7.5 2015-05-07 19:52:06+00:00        -73.999817
# 1               7.7 2009-07-17 20:04:56+00:00        -73.994355
# 2              12.9 2009-08-24 21:45:00+00:00        -74.005043
# 3               5.3 2009-06-26 08:22:21+00:00        -73.976124
# 4              16.0 2014-08-28 17:47:00+00:00        -73.925023
# ...             ...                       ...               ...
# 199995          3.0 2012-10-28 10:49:00+00:00        -73.987042
# 199996          7.5 2014-03-14 01:09:00+00:00        -73.984722
# 199997         30.9 2009-06-29 00:42:00+00:00        -73.986017
# 199998         14.5 2015-05-20 14:56:25+00:00        -73.997124
# 199999         14.1 2010-05-15 04:08:00+00:00        -73.984395
#
#         pickup_latitude  dropoff_longitude  dropoff_latitude  passenger_count  \
# 0             40.738354         -73.999512         40.723217                1
# 1             40.728225         -73.994710         40.750325                1
# 2             40.740770         -73.962565         40.772647                1
# 3             40.790844         -73.965316         40.803349                3
# 4             40.744085         -73.973082         40.761247                5
# ...                 ...                ...               ...              ...
# 199995        40.739367         -73.986525         40.740297                1
# 199996        40.736837         -74.006672         40.739620                1
# 199997        40.756487         -73.858957         40.692588                2
# 199998        40.725452         -73.983215         40.695415                1
# 199999        40.720077         -73.985508         40.768793                1
#
#         Year  Month  Day Day of Week  Day of Week_num  Hour   distance
# 0       2015      5    7         Thu                3    19   1.681111
# 1       2009      7   17         Fri                4    20   2.454363
# 2       2009      8   24         Mon                0    21   5.039603
# 3       2009      6   26         Fri                4     8   1.661442
# 4       2014      8   28         Thu                3    17   4.483730
# ...      ...    ...  ...         ...              ...   ...        ...
# 199995  2012     10   28         Sun                6    10   0.112128
# 199996  2014      3   14         Fri                4     1   1.879635
# 199997  2009      6   29         Mon                0     0  12.867916
# 199998  2015      5   20         Wed                2    14   3.536552
# 199999  2010      5   15         Sat                5     4   5.410678
#
# [199970 rows x 14 columns]

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.linear_model import LinearRegression

# %%
X = df.drop('fare_amount', axis=1)
y = df['fare_amount']

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2)

# %%
cat = df.select_dtypes(['object'])
cat_cols=cat.columns.to_list()
num_cols=X.select_dtypes(['int64','float64']).columns.to_list()
num_cols
# Out:
# ['pickup_longitude',
#  'pickup_latitude',
#  'dropoff_longitude',
#  'dropoff_latitude',
#  'passenger_count',
#  'Year',
#  'Month',
#  'Day',
#  'Day of Week_num',
#  'Hour',
#  'distance']

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), num_cols),
        ('cat', OneHotEncoder(), cat_cols)
    ])

# %%
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_squared_error,mean_absolute_error
models = {
    'Linear Regression': LinearRegression(),
    'Ridge Regression': Ridge(),
    'Lasso Regression': Lasso(),
    'Random Forest': RandomForestRegressor(),
    'Gradient Boosting': GradientBoostingRegressor()
}

# %%
predictions={}
for model_name, model in models.items():
    pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('regressor', model)])
    pipeline.fit(X_train, y_train)
    y_pred=pipeline.predict(X_test)
    predictions[model_name] = y_pred
    print(model_name)
    print('Mean Absolute Error: ',mean_absolute_error(y_test,y_pred))
    print('Mean Squared Error: ',mean_squared_error(y_test,y_pred))
    print('RMSE:',np.sqrt(mean_squared_error(y_test,y_pred)))
    print()
# Out:
# Linear Regression
# Mean Absolute Error:  5.988546284357358
# Mean Squared Error:  104.5273960887439
# RMSE: 10.223864048819502
#
# Ridge Regression
# Mean Absolute Error:  5.989419183460384
# Mean Squared Error:  104.52722448917277
# RMSE: 10.22385565670666
#
# Lasso Regression
# Mean Absolute Error:  6.041758263813396
# Mean Squared Error:  105.73810413191362
# RMSE: 10.282903487435522
#
# Random Forest
# Mean Absolute Error:  1.9965451072422769
# Mean Squared Error:  28.169156852736734
# RMSE: 5.307462374123507
#
# Gradient Boosting
# Mean Absolute Error:  2.1136974677806273
# Mean Squared Error:  29.259073853598203
# RMSE: 5.409165726209376

# %%
pipleline= Pipeline([('preprocessor',preprocessor),('regressor',GradientBoostingRegressor())])
pipleline.fit(X,y)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['pickup_longitude',
#                                                    'pickup_latitude',
#                                                    'dropoff_longitude',
#                                                    'dropoff_latitude',
#                                                    'passenger_count', 'Year',
#                                                    'Month', 'Day',
#                                                    'Day of Week_num', 'Hour',
#                                                    'distance']),
#                                                  ('cat', OneHotEncoder(),
#                                                   ['Day of Week'])])),
#                 ('regressor', GradientBoostingRegressor())])

# %%
import joblib
joblib.dump(pipleline,'pipeline.joblib')
# Out:
# ['pipeline.joblib']
