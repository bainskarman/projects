# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas_datareader import data
from datetime import datetime, timedelta
import yfinance as yf
from fbprophet import Prophet
from fbprophet.plot import plot_plotly
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /workspaces/projects/Stock_predict/notebook2.ipynb Cell 1 line 7
#       <a href='vscode-notebook-cell://codespaces%2Borganic-space-disco-9vx5jq94q9w3wg4/workspaces/projects/Stock_predict/notebook2.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> from datetime import datetime, timedelta
#       <a href='vscode-notebook-cell://codespaces%2Borganic-space-disco-9vx5jq94q9w3wg4/workspaces/projects/Stock_predict/notebook2.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a> import yfinance as yf
# ----> <a href='vscode-notebook-cell://codespaces%2Borganic-space-disco-9vx5jq94q9w3wg4/workspaces/projects/Stock_predict/notebook2.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a> from fbprophet import Prophet
#       <a href='vscode-notebook-cell://codespaces%2Borganic-space-disco-9vx5jq94q9w3wg4/workspaces/projects/Stock_predict/notebook2.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a> from fbprophet.plot import plot_plotly
#
# ModuleNotFoundError: No module named 'fbprophet'

# %%
pip install fbprophet
# Out:
# Collecting fbprophet
#   Downloading fbprophet-0.7.1.tar.gz (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.0/64.0 kB 1.5 MB/s eta 0:00:00ta 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting Cython>=0.22 (from fbprophet)
#   Downloading Cython-3.0.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.2 kB)
# Collecting cmdstanpy==0.9.5 (from fbprophet)
#   Downloading cmdstanpy-0.9.5-py3-none-any.whl (37 kB)
# Collecting pystan>=2.14 (from fbprophet)
#   Downloading pystan-3.7.0-py3-none-any.whl (13 kB)
# Requirement already satisfied: numpy>=1.15.4 in /home/codespace/.local/lib/python3.10/site-packages (from fbprophet) (1.26.2)
# Requirement already satisfied: pandas>=1.0.4 in /home/codespace/.local/lib/python3.10/site-packages (from fbprophet) (2.1.3)
# Requirement already satisfied: matplotlib>=2.0.0 in /home/codespace/.local/lib/python3.10/site-packages (from fbprophet) (3.8.1)
# Collecting LunarCalendar>=0.0.9 (from fbprophet)
#   Downloading LunarCalendar-0.0.9-py2.py3-none-any.whl (18 kB)
# Collecting convertdate>=2.1.2 (from fbprophet)
#   Downloading convertdate-2.4.0-py3-none-any.whl (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.9/47.9 kB 1.1 MB/s eta 0:00:00ta 0:00:01
# Collecting holidays>=0.10.2 (from fbprophet)
#   Downloading holidays-0.38-py3-none-any.whl.metadata (21 kB)
# Collecting setuptools-git>=1.2 (from fbprophet)
#   Downloading setuptools_git-1.2-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: python-dateutil>=2.8.0 in /home/codespace/.local/lib/python3.10/site-packages (from fbprophet) (2.8.2)
# Collecting tqdm>=4.36.1 (from fbprophet)
#   Downloading tqdm-4.66.1-py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 1.3 MB/s eta 0:00:00ta 0:00:01
# Collecting pymeeus<=1,>=0.3.13 (from convertdate>=2.1.2->fbprophet)
#   Downloading PyMeeus-0.5.12.tar.gz (5.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 53.5 MB/s eta 0:00:00:00:0100:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting ephem>=3.7.5.3 (from LunarCalendar>=0.0.9->fbprophet)
#   Downloading ephem-4.1.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.0 kB)
# Requirement already satisfied: pytz in /home/codespace/.local/lib/python3.10/site-packages (from LunarCalendar>=0.0.9->fbprophet) (2023.3.post1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib>=2.0.0->fbprophet) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib>=2.0.0->fbprophet) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib>=2.0.0->fbprophet) (4.44.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib>=2.0.0->fbprophet) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib>=2.0.0->fbprophet) (23.2)
# Requirement already satisfied: pillow>=8 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib>=2.0.0->fbprophet) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib>=2.0.0->fbprophet) (3.1.1)
# Requirement already satisfied: tzdata>=2022.1 in /home/codespace/.local/lib/python3.10/site-packages (from pandas>=1.0.4->fbprophet) (2023.3)
# Collecting aiohttp<4.0,>=3.6 (from pystan>=2.14->fbprophet)
#   Downloading aiohttp-3.9.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.4 kB)
# Collecting clikit<0.7,>=0.6 (from pystan>=2.14->fbprophet)
#   Downloading clikit-0.6.2-py2.py3-none-any.whl (91 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.8/91.8 kB 2.2 MB/s eta 0:00:00ta 0:00:01
# Collecting httpstan<4.11,>=4.10 (from pystan>=2.14->fbprophet)
#   Downloading httpstan-4.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.2 kB)
# Collecting pysimdjson<6.0.0,>=5.0.2 (from pystan>=2.14->fbprophet)
#   Downloading pysimdjson-5.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 31.3 MB/s eta 0:00:00:00:01
# Requirement already satisfied: setuptools in /home/codespace/.local/lib/python3.10/site-packages (from pystan>=2.14->fbprophet) (68.2.2)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.10/site-packages (from python-dateutil>=2.8.0->fbprophet) (1.16.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/codespace/.local/lib/python3.10/site-packages (from aiohttp<4.0,>=3.6->pystan>=2.14->fbprophet) (23.1.0)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0,>=3.6->pystan>=2.14->fbprophet)
#   Downloading multidict-6.0.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 2.8 MB/s eta 0:00:0000:01
# Collecting yarl<2.0,>=1.0 (from aiohttp<4.0,>=3.6->pystan>=2.14->fbprophet)
#   Downloading yarl-1.9.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (28 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0,>=3.6->pystan>=2.14->fbprophet)
#   Downloading frozenlist-1.4.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.2 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp<4.0,>=3.6->pystan>=2.14->fbprophet)
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting async-timeout<5.0,>=4.0 (from aiohttp<4.0,>=3.6->pystan>=2.14->fbprophet)
#   Downloading async_timeout-4.0.3-py3-none-any.whl.metadata (4.2 kB)
# Collecting crashtest<0.4.0,>=0.3.0 (from clikit<0.7,>=0.6->pystan>=2.14->fbprophet)
#   Downloading crashtest-0.3.1-py3-none-any.whl (7.0 kB)
# Collecting pastel<0.3.0,>=0.2.0 (from clikit<0.7,>=0.6->pystan>=2.14->fbprophet)
#   Downloading pastel-0.2.1-py2.py3-none-any.whl (6.0 kB)
# Collecting pylev<2.0,>=1.3 (from clikit<0.7,>=0.6->pystan>=2.14->fbprophet)
#   Downloading pylev-1.4.0-py2.py3-none-any.whl (6.1 kB)
# Collecting appdirs<2.0,>=1.4 (from httpstan<4.11,>=4.10->pystan>=2.14->fbprophet)
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Collecting marshmallow<4.0,>=3.10 (from httpstan<4.11,>=4.10->pystan>=2.14->fbprophet)
#   Downloading marshmallow-3.20.1-py3-none-any.whl.metadata (7.8 kB)
# Collecting webargs<9.0,>=8.0 (from httpstan<4.11,>=4.10->pystan>=2.14->fbprophet)
#   Downloading webargs-8.3.0-py3-none-any.whl.metadata (8.1 kB)
# Requirement already satisfied: idna>=2.0 in /home/codespace/.local/lib/python3.10/site-packages (from yarl<2.0,>=1.0->aiohttp<4.0,>=3.6->pystan>=2.14->fbprophet) (3.4)
# Downloading Cython-3.0.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 45.5 MB/s eta 0:00:00:00:01
# Downloading holidays-0.38-py3-none-any.whl (854 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 854.3/854.3 kB 17.3 MB/s eta 0:00:0000:01
# Downloading tqdm-4.66.1-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 kB 2.0 MB/s eta 0:00:00eta 0:00:01
# Downloading aiohttp-3.9.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 23.1 MB/s eta 0:00:00:00:01
# Downloading ephem-4.1.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 32.0 MB/s eta 0:00:00:00:01
# Downloading httpstan-4.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (44.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 MB 30.4 MB/s eta 0:00:00:00:0100:01
# Downloading async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Downloading frozenlist-1.4.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (225 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 225.7/225.7 kB 5.9 MB/s eta 0:00:00:00:01
# Downloading marshmallow-3.20.1-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 1.2 MB/s eta 0:00:00
# Downloading webargs-8.3.0-py3-none-any.whl (31 kB)
# Downloading yarl-1.9.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (300 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.7/300.7 kB 7.3 MB/s eta 0:00:00:00:01
# Building wheels for collected packages: fbprophet, pymeeus
#   Building wheel for fbprophet (pyproject.toml) ... error
#   error: subprocess-exited-with-error
#
#   × Building wheel for fbprophet (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [59 lines of output]
#       <string>:10: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#       running bdist_wheel
#       running build
#       running build_py
#       creating build
#       creating build/lib
#       creating build/lib/fbprophet
#       creating build/lib/fbprophet/stan_model
#       Traceback (most recent call last):
#         File "/home/codespace/.python/current/lib/python3.10/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 353, in <module>
#           main()
#         File "/home/codespace/.python/current/lib/python3.10/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 335, in main
#           json_out['return_val'] = hook(**hook_input['kwargs'])
#         File "/home/codespace/.python/current/lib/python3.10/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 251, in build_wheel
#           return _build_backend().build_wheel(wheel_directory, config_settings,
#         File "/tmp/pip-build-env-d1g8me6t/overlay/lib/python3.10/site-packages/setuptools/build_meta.py", line 404, in build_wheel
#           return self._build_with_temp_dir(
#         File "/tmp/pip-build-env-d1g8me6t/overlay/lib/python3.10/site-packages/setuptools/build_meta.py", line 389, in _build_with_temp_dir
#           self.run_setup()
#         File "/tmp/pip-build-env-d1g8me6t/overlay/lib/python3.10/site-packages/setuptools/build_meta.py", line 480, in run_setup
#           super(_BuildMetaLegacyBackend, self).run_setup(setup_script=setup_script)
#         File "/tmp/pip-build-env-d1g8me6t/overlay/lib/python3.10/site-packages/setuptools/build_meta.py", line 311, in run_setup
#           exec(code, locals())
#         File "<string>", line 122, in <module>
#         File "/tmp/pip-build-env-d1g8me6t/overlay/lib/python3.10/site-packages/setuptools/__init__.py", line 103, in setup
#           return distutils.core.setup(**attrs)
#         File "/tmp/pip-build-env-d1g8me6t/overlay/lib/python3.10/site-packages/setuptools/_distutils/core.py", line 185, in setup
#           return run_commands(dist)
#         File "/tmp/pip-build-env-d1g8me6t/overlay/lib/python3.10/site-packages/setuptools/_distutils/core.py", line 201, in run_commands
#           dist.run_commands()
#         File "/tmp/pip-build-env-d1g8me6t/overlay/lib/python3.10/site-packages/setuptools/_distutils/dist.py", line 969, in run_commands
#           self.run_command(cmd)
#         File "/tmp/pip-build-env-d1g8me6t/overlay/lib/python3.10/site-packages/setuptools/dist.py", line 963, in run_command
#           super().run_command(command)
#         File "/tmp/pip-build-env-d1g8me6t/overlay/lib/python3.10/site-packages/setuptools/_distutils/dist.py", line 988, in run_command
#           cmd_obj.run()
#         File "/tmp/pip-build-env-d1g8me6t/overlay/lib/python3.10/site-packages/wheel/bdist_wheel.py", line 368, in run
#           self.run_command("build")
#         File "/tmp/pip-build-env-d1g8me6t/overlay/lib/python3.10/site-packages/setuptools/_distutils/cmd.py", line 318, in run_command
#           self.distribution.run_command(command)
#         File "/tmp/pip-build-env-d1g8me6t/overlay/lib/python3.10/site-packages/setuptools/dist.py", line 963, in run_command
#           super().run_command(command)
#         File "/tmp/pip-build-env-d1g8me6t/overlay/lib/python3.10/site-packages/setuptools/_distutils/dist.py", line 988, in run_command
#           cmd_obj.run()
#         File "/tmp/pip-build-env-d1g8me6t/overlay/lib/python3.10/site-packages/setuptools/_distutils/command/build.py", line 131, in run
#           self.run_command(cmd_name)
#         File "/tmp/pip-build-env-d1g8me6t/overlay/lib/python3.10/site-packages/setuptools/_distutils/cmd.py", line 318, in run_command
#           self.distribution.run_command(command)
#         File "/tmp/pip-build-env-d1g8me6t/overlay/lib/python3.10/site-packages/setuptools/dist.py", line 963, in run_command
#           super().run_command(command)
#         File "/tmp/pip-build-env-d1g8me6t/overlay/lib/python3.10/site-packages/setuptools/_distutils/dist.py", line 988, in run_command
#           cmd_obj.run()
#         File "<string>", line 48, in run
#         File "<string>", line 36, in build_models
#         File "/tmp/pip-install-hpa0y2p9/fbprophet_05f872c64a5e49c4af32501ffe0ce71d/fbprophet/__init__.py", line 8, in <module>
#           from fbprophet.forecaster import Prophet
#         File "/tmp/pip-install-hpa0y2p9/fbprophet_05f872c64a5e49c4af32501ffe0ce71d/fbprophet/forecaster.py", line 14, in <module>
#           import numpy as np
#       ModuleNotFoundError: No module named 'numpy'
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for fbprophet
#   Building wheel for pymeeus (pyproject.toml) ... done
#   Created wheel for pymeeus: filename=PyMeeus-0.5.12-py3-none-any.whl size=732001 sha256=55458052408dc6df644fc090f2d7d2d5e634b069a4c95bd9c1dc3074346ca656
#   Stored in directory: /home/codespace/.cache/pip/wheels/d6/67/78/aa2e8d108639dd23a5e9e72a4fc88bb44f5541894382712f48
# Successfully built pymeeus
# Failed to build fbprophet
# ERROR: Could not build wheels for fbprophet, which is required to install pyproject.toml-based projects
# Note: you may need to restart the kernel to use updated packages.

# %%
import streamlit as st
from datetime import date

import yfinance as yf
from fbprophet import Prophet
from fbprophet.plot import plot_plotly
from plotly import graph_objs as go

START = "2015-01-01"
TODAY = date.today().strftime("%Y-%m-%d")

st.title('Stock Forecast App')

stocks = ('GOOG', 'AAPL', 'MSFT', 'GME')
selected_stock = st.selectbox('Select dataset for prediction', stocks)

n_years = st.slider('Years of prediction:', 1, 4)
period = n_years * 365


@st.cache
def load_data(ticker):
    data = yf.download(ticker, START, TODAY)
    data.reset_index(inplace=True)
    return data

	
data_load_state = st.text('Loading data...')
data = load_data(selected_stock)
data_load_state.text('Loading data... done!')

st.subheader('Raw data')
st.write(data.tail())

# Plot raw data
def plot_raw_data():
	fig = go.Figure()
	fig.add_trace(go.Scatter(x=data['Date'], y=data['Open'], name="stock_open"))
	fig.add_trace(go.Scatter(x=data['Date'], y=data['Close'], name="stock_close"))
	fig.layout.update(title_text='Time Series data with Rangeslider', xaxis_rangeslider_visible=True)
	st.plotly_chart(fig)
	
plot_raw_data()

# Predict forecast with Prophet.
df_train = data[['Date','Close']]
df_train = df_train.rename(columns={"Date": "ds", "Close": "y"})

m = Prophet()
m.fit(df_train)
future = m.make_future_dataframe(periods=period)
forecast = m.predict(future)

# Show and plot forecast
st.subheader('Forecast data')
st.write(forecast.tail())
    
st.write(f'Forecast plot for {n_years} years')
fig1 = plot_plotly(m, forecast)
st.plotly_chart(fig1)

st.write("Forecast components")
fig2 = m.plot_components(forecast)
st.write(fig2)
