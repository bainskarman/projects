# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas_datareader import data
from datetime import datetime, timedelta
import yfinance as yf
from fbprophet import Prophet
from fbprophet.plot import plot_plotly
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /workspaces/projects/Stock_predict/notebook2.ipynb Cell 1 line 7
#       <a href='vscode-notebook-cell://codespaces%2Borganic-space-disco-9vx5jq94q9w3wg4/workspaces/projects/Stock_predict/notebook2.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> from datetime import datetime, timedelta
#       <a href='vscode-notebook-cell://codespaces%2Borganic-space-disco-9vx5jq94q9w3wg4/workspaces/projects/Stock_predict/notebook2.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a> import yfinance as yf
# ----> <a href='vscode-notebook-cell://codespaces%2Borganic-space-disco-9vx5jq94q9w3wg4/workspaces/projects/Stock_predict/notebook2.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a> from fbprophet import Prophet
#       <a href='vscode-notebook-cell://codespaces%2Borganic-space-disco-9vx5jq94q9w3wg4/workspaces/projects/Stock_predict/notebook2.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a> from fbprophet.plot import plot_plotly
#
# ModuleNotFoundError: No module named 'fbprophet'

# %%
pip install fbprophet
# Out:
# Collecting fbprophet
#   Using cached fbprophet-0.7.1.tar.gz (64 kB)
#   Preparing metadata (setup.py) ... done
# Collecting Cython>=0.22 (from fbprophet)
#   Using cached Cython-3.0.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.2 kB)
# Collecting cmdstanpy==0.9.5 (from fbprophet)
#   Using cached cmdstanpy-0.9.5-py3-none-any.whl (37 kB)
# Requirement already satisfied: pystan>=2.14 in /workspaces/projects/.conda/lib/python3.10/site-packages (from fbprophet) (3.7.0)
# Requirement already satisfied: numpy>=1.15.4 in /home/codespace/.local/lib/python3.10/site-packages (from fbprophet) (1.26.2)
# Requirement already satisfied: pandas>=1.0.4 in /home/codespace/.local/lib/python3.10/site-packages (from fbprophet) (2.1.3)
# Requirement already satisfied: matplotlib>=2.0.0 in /home/codespace/.local/lib/python3.10/site-packages (from fbprophet) (3.8.1)
# Collecting LunarCalendar>=0.0.9 (from fbprophet)
#   Using cached LunarCalendar-0.0.9-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: convertdate>=2.1.2 in /workspaces/projects/.conda/lib/python3.10/site-packages (from fbprophet) (2.4.0)
# Requirement already satisfied: holidays>=0.10.2 in /workspaces/projects/.conda/lib/python3.10/site-packages (from fbprophet) (0.38)
# Collecting setuptools-git>=1.2 (from fbprophet)
#   Using cached setuptools_git-1.2-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: python-dateutil>=2.8.0 in /home/codespace/.local/lib/python3.10/site-packages (from fbprophet) (2.8.2)
# Requirement already satisfied: tqdm>=4.36.1 in /workspaces/projects/.conda/lib/python3.10/site-packages (from fbprophet) (4.66.1)
# Requirement already satisfied: pymeeus<=1,>=0.3.13 in /workspaces/projects/.conda/lib/python3.10/site-packages (from convertdate>=2.1.2->fbprophet) (0.5.12)
# Collecting ephem>=3.7.5.3 (from LunarCalendar>=0.0.9->fbprophet)
#   Using cached ephem-4.1.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.0 kB)
# Requirement already satisfied: pytz in /home/codespace/.local/lib/python3.10/site-packages (from LunarCalendar>=0.0.9->fbprophet) (2023.3.post1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib>=2.0.0->fbprophet) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib>=2.0.0->fbprophet) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib>=2.0.0->fbprophet) (4.44.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib>=2.0.0->fbprophet) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib>=2.0.0->fbprophet) (23.2)
# Requirement already satisfied: pillow>=8 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib>=2.0.0->fbprophet) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib>=2.0.0->fbprophet) (3.1.1)
# Requirement already satisfied: tzdata>=2022.1 in /home/codespace/.local/lib/python3.10/site-packages (from pandas>=1.0.4->fbprophet) (2023.3)
# Requirement already satisfied: aiohttp<4.0,>=3.6 in /workspaces/projects/.conda/lib/python3.10/site-packages (from pystan>=2.14->fbprophet) (3.9.1)
# Requirement already satisfied: clikit<0.7,>=0.6 in /workspaces/projects/.conda/lib/python3.10/site-packages (from pystan>=2.14->fbprophet) (0.6.2)
# Requirement already satisfied: httpstan<4.11,>=4.10 in /workspaces/projects/.conda/lib/python3.10/site-packages (from pystan>=2.14->fbprophet) (4.10.1)
# Requirement already satisfied: pysimdjson<6.0.0,>=5.0.2 in /workspaces/projects/.conda/lib/python3.10/site-packages (from pystan>=2.14->fbprophet) (5.0.2)
# Requirement already satisfied: setuptools in /home/codespace/.local/lib/python3.10/site-packages (from pystan>=2.14->fbprophet) (68.2.2)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.10/site-packages (from python-dateutil>=2.8.0->fbprophet) (1.16.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/codespace/.local/lib/python3.10/site-packages (from aiohttp<4.0,>=3.6->pystan>=2.14->fbprophet) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /workspaces/projects/.conda/lib/python3.10/site-packages (from aiohttp<4.0,>=3.6->pystan>=2.14->fbprophet) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /workspaces/projects/.conda/lib/python3.10/site-packages (from aiohttp<4.0,>=3.6->pystan>=2.14->fbprophet) (1.9.3)
# Requirement already satisfied: frozenlist>=1.1.1 in /workspaces/projects/.conda/lib/python3.10/site-packages (from aiohttp<4.0,>=3.6->pystan>=2.14->fbprophet) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /workspaces/projects/.conda/lib/python3.10/site-packages (from aiohttp<4.0,>=3.6->pystan>=2.14->fbprophet) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /workspaces/projects/.conda/lib/python3.10/site-packages (from aiohttp<4.0,>=3.6->pystan>=2.14->fbprophet) (4.0.3)
# Requirement already satisfied: crashtest<0.4.0,>=0.3.0 in /workspaces/projects/.conda/lib/python3.10/site-packages (from clikit<0.7,>=0.6->pystan>=2.14->fbprophet) (0.3.1)
# Requirement already satisfied: pastel<0.3.0,>=0.2.0 in /workspaces/projects/.conda/lib/python3.10/site-packages (from clikit<0.7,>=0.6->pystan>=2.14->fbprophet) (0.2.1)
# Requirement already satisfied: pylev<2.0,>=1.3 in /workspaces/projects/.conda/lib/python3.10/site-packages (from clikit<0.7,>=0.6->pystan>=2.14->fbprophet) (1.4.0)
# Requirement already satisfied: appdirs<2.0,>=1.4 in /workspaces/projects/.conda/lib/python3.10/site-packages (from httpstan<4.11,>=4.10->pystan>=2.14->fbprophet) (1.4.4)
# Requirement already satisfied: marshmallow<4.0,>=3.10 in /workspaces/projects/.conda/lib/python3.10/site-packages (from httpstan<4.11,>=4.10->pystan>=2.14->fbprophet) (3.20.1)
# Requirement already satisfied: webargs<9.0,>=8.0 in /workspaces/projects/.conda/lib/python3.10/site-packages (from httpstan<4.11,>=4.10->pystan>=2.14->fbprophet) (8.3.0)
# Requirement already satisfied: idna>=2.0 in /home/codespace/.local/lib/python3.10/site-packages (from yarl<2.0,>=1.0->aiohttp<4.0,>=3.6->pystan>=2.14->fbprophet) (3.4)
# Using cached Cython-3.0.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
# Using cached ephem-4.1.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.8 MB)
# Building wheels for collected packages: fbprophet
#   Building wheel for fbprophet (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [55 lines of output]
#       /tmp/pip-install-pp6kmjep/fbprophet_3c4071b95a1e443dbd611b580bd9404a/setup.py:10: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#         from pkg_resources import (
#       running bdist_wheel
#       running build
#       running build_py
#       creating build
#       creating build/lib
#       creating build/lib/fbprophet
#       creating build/lib/fbprophet/stan_model
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 34, in <module>
#         File "/tmp/pip-install-pp6kmjep/fbprophet_3c4071b95a1e443dbd611b580bd9404a/setup.py", line 122, in <module>
#           setup(
#         File "/home/codespace/.local/lib/python3.10/site-packages/setuptools/__init__.py", line 103, in setup
#           return distutils.core.setup(**attrs)
#         File "/home/codespace/.local/lib/python3.10/site-packages/setuptools/_distutils/core.py", line 185, in setup
#           return run_commands(dist)
#         File "/home/codespace/.local/lib/python3.10/site-packages/setuptools/_distutils/core.py", line 201, in run_commands
#           dist.run_commands()
#         File "/home/codespace/.local/lib/python3.10/site-packages/setuptools/_distutils/dist.py", line 969, in run_commands
#           self.run_command(cmd)
#         File "/home/codespace/.local/lib/python3.10/site-packages/setuptools/dist.py", line 989, in run_command
#           super().run_command(command)
#         File "/home/codespace/.local/lib/python3.10/site-packages/setuptools/_distutils/dist.py", line 988, in run_command
#           cmd_obj.run()
#         File "/workspaces/projects/.conda/lib/python3.10/site-packages/wheel/bdist_wheel.py", line 364, in run
#           self.run_command("build")
#         File "/home/codespace/.local/lib/python3.10/site-packages/setuptools/_distutils/cmd.py", line 318, in run_command
#           self.distribution.run_command(command)
#         File "/home/codespace/.local/lib/python3.10/site-packages/setuptools/dist.py", line 989, in run_command
#           super().run_command(command)
#         File "/home/codespace/.local/lib/python3.10/site-packages/setuptools/_distutils/dist.py", line 988, in run_command
#           cmd_obj.run()
#         File "/home/codespace/.local/lib/python3.10/site-packages/setuptools/_distutils/command/build.py", line 131, in run
#           self.run_command(cmd_name)
#         File "/home/codespace/.local/lib/python3.10/site-packages/setuptools/_distutils/cmd.py", line 318, in run_command
#           self.distribution.run_command(command)
#         File "/home/codespace/.local/lib/python3.10/site-packages/setuptools/dist.py", line 989, in run_command
#           super().run_command(command)
#         File "/home/codespace/.local/lib/python3.10/site-packages/setuptools/_distutils/dist.py", line 988, in run_command
#           cmd_obj.run()
#         File "/tmp/pip-install-pp6kmjep/fbprophet_3c4071b95a1e443dbd611b580bd9404a/setup.py", line 48, in run
#           build_models(target_dir)
#         File "/tmp/pip-install-pp6kmjep/fbprophet_3c4071b95a1e443dbd611b580bd9404a/setup.py", line 36, in build_models
#           from fbprophet.models import StanBackendEnum
#         File "/tmp/pip-install-pp6kmjep/fbprophet_3c4071b95a1e443dbd611b580bd9404a/fbprophet/__init__.py", line 8, in <module>
#           from fbprophet.forecaster import Prophet
#         File "/tmp/pip-install-pp6kmjep/fbprophet_3c4071b95a1e443dbd611b580bd9404a/fbprophet/forecaster.py", line 17, in <module>
#           from fbprophet.make_holidays import get_holiday_names, make_holidays_df
#         File "/tmp/pip-install-pp6kmjep/fbprophet_3c4071b95a1e443dbd611b580bd9404a/fbprophet/make_holidays.py", line 14, in <module>
#           import fbprophet.hdays as hdays_part2
#         File "/tmp/pip-install-pp6kmjep/fbprophet_3c4071b95a1e443dbd611b580bd9404a/fbprophet/hdays.py", line 14, in <module>
#           from lunarcalendar import Lunar, Converter
#       ModuleNotFoundError: No module named 'lunarcalendar'
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for fbprophet
#   Running setup.py clean for fbprophet
# Failed to build fbprophet
# ERROR: Could not build wheels for fbprophet, which is required to install pyproject.toml-based projects
# Note: you may need to restart the kernel to use updated packages.

# %%
import streamlit as st
from datetime import date

import yfinance as yf
from fbprophet import Prophet
from fbprophet.plot import plot_plotly
from plotly import graph_objs as go

START = "2015-01-01"
TODAY = date.today().strftime("%Y-%m-%d")

st.title('Stock Forecast App')

stocks = ('GOOG', 'AAPL', 'MSFT', 'GME')
selected_stock = st.selectbox('Select dataset for prediction', stocks)

n_years = st.slider('Years of prediction:', 1, 4)
period = n_years * 365


@st.cache
def load_data(ticker):
    data = yf.download(ticker, START, TODAY)
    data.reset_index(inplace=True)
    return data

	
data_load_state = st.text('Loading data...')
data = load_data(selected_stock)
data_load_state.text('Loading data... done!')

st.subheader('Raw data')
st.write(data.tail())

# Plot raw data
def plot_raw_data():
	fig = go.Figure()
	fig.add_trace(go.Scatter(x=data['Date'], y=data['Open'], name="stock_open"))
	fig.add_trace(go.Scatter(x=data['Date'], y=data['Close'], name="stock_close"))
	fig.layout.update(title_text='Time Series data with Rangeslider', xaxis_rangeslider_visible=True)
	st.plotly_chart(fig)
	
plot_raw_data()

# Predict forecast with Prophet.
df_train = data[['Date','Close']]
df_train = df_train.rename(columns={"Date": "ds", "Close": "y"})

m = Prophet()
m.fit(df_train)
future = m.make_future_dataframe(periods=period)
forecast = m.predict(future)

# Show and plot forecast
st.subheader('Forecast data')
st.write(forecast.tail())
    
st.write(f'Forecast plot for {n_years} years')
fig1 = plot_plotly(m, forecast)
st.plotly_chart(fig1)

st.write("Forecast components")
fig2 = m.plot_components(forecast)
st.write(fig2)
