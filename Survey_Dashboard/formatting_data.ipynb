# %%
import pandas as pd

# %%
canada = pd.read_csv('/workspaces/projects/Dash/linkedin-jobs-canada.csv')
canada
# Out:
#                                            title  \
# 0                                   Data Analyst
# 1                                   Data Analyst
# 2                                   Data Analyst
# 3                                   Data Analyst
# 4                                   Data Analyst
# ...                                          ...
# 2768   Data Analyst, Flight Pricing Optimization
# 2769  Sector Data Analyst, Data Driven Investing
# 2770                                Data Analyst
# 2771                                Data Analyst
# 2772                                Data Analyst
#
#                                     company  \
# 0                                   Axonify
# 1                                B3 Systems
# 2                            Wood Mackenzie
# 3                   LOFT Community Services
# 4                              NAM Info Inc
# ...                                     ...
# 2768                              Priceline
# ...
