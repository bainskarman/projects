# %% [markdown]
# ## Installing Necessary Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# #### Datasets

# %%
deliveries= pd.read_csv("IPL_BALLS_2008_2022.csv")
matches=pd.read_csv("IPL_MATCHES_2008_2022.csv")

# %% [markdown]
# #### Pre Inspection

# %%
matches.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# 3             Eden Gardens, Kolkata        Gujarat Titans        field
# 4          Wankhede Stadium, Mumbai   Sunrisers Hyderabad          bat
#
#   SuperOver                  WinningTeam    WonBy  Margin method  \
# 0         N               Gujarat Titans  Wickets     7.0    NaN
# 1         N             Rajasthan Royals  Wickets     7.0    NaN
# 2         N  Royal Challengers Bangalore     Runs    14.0    NaN
# 3         N               Gujarat Titans  Wickets     7.0    NaN
# 4         N                 Punjab Kings  Wickets     5.0    NaN
#
#   Player_of_Match                                       Team1Players  \
# 0       HH Pandya  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1      JC Buttler  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 2      RM Patidar  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 3       DA Miller  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 4   Harpreet Brar  ['PK Garg', 'Abhishek Sharma', 'RA Tripathi', ...
#
#                                         Team2Players        Umpire1  \
# 0  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...    CB Gaffaney
# 1  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...    CB Gaffaney
# 2  ['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda...  J Madanagopal
# 3  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...   BNJ Oxenford
# 4  ['JM Bairstow', 'S Dhawan', 'M Shahrukh Khan',...   AK Chaudhary
#
#          Umpire2
# 0    Nitin Menon
# 1    Nitin Menon
# 2       MA Gough
# 3      VK Sharma
# 4  NA Patwardhan

# %%
deliveries.head()
# Out:
#         ID  innings  overs  ballnumber       batter          bowler  \
# 0  1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1  1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2  1312200        1      0           3   JC Buttler  Mohammed Shami
# 3  1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4  1312200        1      0           5  YBK Jaiswal  Mohammed Shami
#
#    non-striker extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 0   JC Buttler        NaN            0           0          0             0
# 1   JC Buttler    legbyes            0           1          1             0
# 2  YBK Jaiswal        NaN            1           0          1             0
# 3   JC Buttler        NaN            0           0          0             0
# 4   JC Buttler        NaN            0           0          0             0
#
#    isWicketDelivery player_out kind fielders_involved       BattingTeam
# 0                 0        NaN  NaN               NaN  Rajasthan Royals
# 1                 0        NaN  NaN               NaN  Rajasthan Royals
# 2                 0        NaN  NaN               NaN  Rajasthan Royals
# 3                 0        NaN  NaN               NaN  Rajasthan Royals
# 4                 0        NaN  NaN               NaN  Rajasthan Royals

# %% [markdown]
# #### Adding total score column in Matches df

# %%
total_score_df= deliveries.groupby(['ID','innings']).sum()['total_run'].reset_index()

# %%
team1_score_df=total_score_df[total_score_df['innings']==1]
team2_score_df=total_score_df[total_score_df['innings']==2]

# %%
team1_score_df.rename(columns={'total_run': 'team1_runs'}, inplace=True)
team2_score_df.rename(columns={'total_run': 'team2_runs'}, inplace=True)
# Out:
# /tmp/ipykernel_4349/2836941195.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   team1_score_df.rename(columns={'total_run': 'team1_runs'}, inplace=True)
# /tmp/ipykernel_4349/2836941195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   team2_score_df.rename(columns={'total_run': 'team2_runs'}, inplace=True)

# %%
matches=matches.merge(team2_score_df[['ID','team2_runs']],on='ID')
matches=matches.merge(team1_score_df[['ID','team1_runs']],on='ID')

# %%
matches
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 943   335986     Kolkata  2008-04-20  2007/08            4
# 944   335985      Mumbai  2008-04-20  2007/08            5
# 945   335984       Delhi  2008-04-19  2007/08            3
# 946   335983  Chandigarh  2008-04-19  2007/08            2
# 947   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# 3               Rajasthan Royals               Gujarat Titans
# 4            Sunrisers Hyderabad                 Punjab Kings
# ..                           ...                          ...
# 943        Kolkata Knight Riders              Deccan Chargers
# 944               Mumbai Indians  Royal Challengers Bangalore
# 945             Delhi Daredevils             Rajasthan Royals
# 946              Kings XI Punjab          Chennai Super Kings
# 947  Royal Challengers Bangalore        Kolkata Knight Riders
#
#                                           Venue                   TossWinner  \
# 0              Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 1              Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 2                         Eden Gardens, Kolkata         Lucknow Super Giants
# 3                         Eden Gardens, Kolkata               Gujarat Titans
# 4                      Wankhede Stadium, Mumbai          Sunrisers Hyderabad
# ..                                          ...                          ...
# 943                                Eden Gardens              Deccan Chargers
# 944                            Wankhede Stadium               Mumbai Indians
# 945                            Feroz Shah Kotla             Rajasthan Royals
# 946  Punjab Cricket Association Stadium, Mohali          Chennai Super Kings
# 947                       M Chinnaswamy Stadium  Royal Challengers Bangalore
#
#     TossDecision  ...    WonBy Margin method  Player_of_Match  \
# 0            bat  ...  Wickets    7.0    NaN        HH Pandya
# 1          field  ...  Wickets    7.0    NaN       JC Buttler
# 2          field  ...     Runs   14.0    NaN       RM Patidar
# 3          field  ...  Wickets    7.0    NaN        DA Miller
# 4            bat  ...  Wickets    5.0    NaN    Harpreet Brar
# ..           ...  ...      ...    ...    ...              ...
# 943          bat  ...  Wickets    5.0    NaN        DJ Hussey
# 944          bat  ...  Wickets    5.0    NaN       MV Boucher
# 945          bat  ...  Wickets    9.0    NaN      MF Maharoof
# 946          bat  ...     Runs   33.0    NaN       MEK Hussey
# 947        field  ...     Runs  140.0    NaN      BB McCullum
#
#                                           Team1Players  \
# 0    ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1    ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 2    ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 3    ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 4    ['PK Garg', 'Abhishek Sharma', 'RA Tripathi', ...
# ..                                                 ...
# 943  ['WP Saha', 'BB McCullum', 'RT Ponting', 'SC G...
# 944  ['L Ronchi', 'ST Jayasuriya', 'DJ Thornely', '...
# 945  ['G Gambhir', 'V Sehwag', 'S Dhawan', 'MK Tiwa...
# 946  ['K Goel', 'JR Hopes', 'KC Sangakkara', 'Yuvra...
# 947  ['R Dravid', 'W Jaffer', 'V Kohli', 'JH Kallis...
#
#                                           Team2Players        Umpire1  \
# 0    ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...    CB Gaffaney
# 1    ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...    CB Gaffaney
# 2    ['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda...  J Madanagopal
# 3    ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...   BNJ Oxenford
# 4    ['JM Bairstow', 'S Dhawan', 'M Shahrukh Khan',...   AK Chaudhary
# ..                                                 ...            ...
# 943  ['AC Gilchrist', 'Y Venugopal Rao', 'VVS Laxma...      BF Bowden
# 944  ['S Chanderpaul', 'R Dravid', 'LRPL Taylor', '...       SJ Davis
# 945  ['T Kohli', 'YK Pathan', 'SR Watson', 'M Kaif'...      Aleem Dar
# 946  ['PA Patel', 'ML Hayden', 'MEK Hussey', 'MS Dh...      MR Benson
# 947  ['SC Ganguly', 'BB McCullum', 'RT Ponting', 'D...      Asad Rauf
#
#             Umpire2 team2_runs team1_runs
# 0       Nitin Menon        133        130
# 1       Nitin Menon        161        157
# 2          MA Gough        193        207
# 3         VK Sharma        191        188
# 4     NA Patwardhan        160        157
# ..              ...        ...        ...
# 943     K Hariharan        112        110
# 944       DJ Harper        166        165
# 945  GA Pratapkumar        132        129
# 946      SL Shastri        207        240
# 947     RE Koertzen         82        222
#
# [948 rows x 22 columns]

# %% [markdown]
# #### Editing Team names to latest ones

# %%
matches['Team1'].unique().tolist()
# Out:
# ['Rajasthan Royals',
#  'Royal Challengers Bangalore',
#  'Sunrisers Hyderabad',
#  'Delhi Capitals',
#  'Chennai Super Kings',
#  'Gujarat Titans',
#  'Lucknow Super Giants',
#  'Kolkata Knight Riders',
#  'Punjab Kings',
#  'Mumbai Indians',
#  'Kings XI Punjab',
#  'Delhi Daredevils',
#  'Rising Pune Supergiant',
#  'Gujarat Lions',
#  'Rising Pune Supergiants',
#  'Pune Warriors',
#  'Deccan Chargers',
#  'Kochi Tuskers Kerala']

# %%
teams=['Rajasthan Royals',
 'Royal Challengers Bangalore',
 'Sunrisers Hyderabad',
 'Delhi Capitals',
 'Chennai Super Kings',
 'Gujarat Titans',
 'Lucknow Super Giants',
 'Kolkata Knight Riders',
 'Punjab Kings',
 'Mumbai Indians']

# %%
matches['Team1']= matches['Team1'].str.replace('Delhi Daredevils','Delhi Capitals')
matches['Team2']= matches['Team2'].str.replace('Delhi Daredevils','Delhi Capitals')
matches['Team1']= matches['Team1'].str.replace('Kings XI Punjab','Punjab Kings')
matches['Team2']= matches['Team2'].str.replace('Kings XI Punjab','Punjab Kings')
matches['Team1']= matches['Team1'].str.replace('Deccan Chargers','Sunrisers Hyderabad')
matches['Team2']= matches['Team2'].str.replace('Deccan Chargers','Sunrisers Hyderabad')
deliveries['BattingTeam'] = deliveries['BattingTeam'].replace({
    'Delhi Daredevils': 'Delhi Capitals',
    'Kings XI Punjab': 'Punjab Kings',
    'Deccan Chargers': 'Sunrisers Hyderabad'
})

# %%
matches=matches[matches['Team1'].isin(teams)]
matches=matches[matches['Team2'].isin(teams)]
deliveries=deliveries[deliveries['BattingTeam'].isin(teams)]

# %% [markdown]
# #### Handling Missing Values in Matches df

# %%
matches.isnull().sum()
# Out:
# ID                   0
# City                51
# Date                 0
# Season               0
# MatchNumber          0
# Team1                0
# Team2                0
# Venue                0
# TossWinner           0
# TossDecision         0
# SuperOver            2
# WinningTeam          2
# WonBy                0
# Margin              15
# method             819
# Player_of_Match      2
# Team1Players         0
# Team2Players         0
# Umpire1              0
# Umpire2              0
# team2_runs           0
# team1_runs           0
# dtype: int64

# %%
matches['City'] = matches.apply(lambda row: row['Venue'].split()[0] if pd.isnull(row['City']) else row['City'], axis=1)

# %%
matches[matches['SuperOver'].isnull()]
# Out:
#           ID       City        Date Season MatchNumber  \
# 205  1178424  Bengaluru  2019-04-30   2019          49
# 437   829813  Bangalore  2015-05-17   2015          55
#
#                            Team1             Team2                  Venue  \
# 205  Royal Challengers Bangalore  Rajasthan Royals  M.Chinnaswamy Stadium
# 437  Royal Challengers Bangalore    Delhi Capitals  M Chinnaswamy Stadium
#
#                       TossWinner TossDecision  ...      WonBy Margin method  \
# 205             Rajasthan Royals        field  ...  NoResults    NaN    NaN
# 437  Royal Challengers Bangalore        field  ...  NoResults    NaN    NaN
#
#      Player_of_Match                                       Team1Players  \
# 205              NaN  ['V Kohli', 'AB de Villiers', 'MP Stoinis', 'H...
# 437              NaN  ['V Kohli', 'CH Gayle', 'AB de Villiers', 'Man...
#
#                                           Team2Players          Umpire1  \
# 205  ['SV Samson', 'LS Livingstone', 'AM Rahane', '...         NJ Llong
# 437  ['Q de Kock', 'SS Iyer', 'JP Duminy', 'Yuvraj ...  HDPK Dharmasena
#
#           Umpire2 team2_runs team1_runs
# 205     UV Gandhe         41         62
# 437  K Srinivasan          2        187
#
# [2 rows x 22 columns]

# %%
matches.dropna(subset=['SuperOver'], inplace=True)

# %%
matches['Margin'].fillna(0, inplace=True)

# %%
matches['method'].fillna('No', inplace=True)

# %%
matches['MatchNumber'] = matches['MatchNumber'].apply(lambda x: 'KO' if x in ['Final', 'Qualifier 2', 'Eliminator', 'Qualifier 1', 'Qualifier', 'Elimination Final', '3rd Place Play-Off', 'Semi Final'] else 'NO')

# %%
matches.head(5).T
# Out:
#                                                                  0  \
# ID                                                         1312200
# City                                                     Ahmedabad
# Date                                                    2022-05-29
# Season                                                        2022
# MatchNumber                                                     KO
# Team1                                             Rajasthan Royals
# Team2                                               Gujarat Titans
# Venue                             Narendra Modi Stadium, Ahmedabad
# TossWinner                                        Rajasthan Royals
# TossDecision                                                   bat
# SuperOver                                                        N
# WinningTeam                                         Gujarat Titans
# WonBy                                                      Wickets
# Margin                                                         7.0
# method                                                          No
# Player_of_Match                                          HH Pandya
# Team1Players     ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# Team2Players     ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...
# Umpire1                                                CB Gaffaney
# Umpire2                                                Nitin Menon
# team2_runs                                                     133
# team1_runs                                                     130
#
#                                                                  1  \
# ID                                                         1312199
# City                                                     Ahmedabad
# Date                                                    2022-05-27
# Season                                                        2022
# MatchNumber                                                     KO
# Team1                                  Royal Challengers Bangalore
# Team2                                             Rajasthan Royals
# Venue                             Narendra Modi Stadium, Ahmedabad
# TossWinner                                        Rajasthan Royals
# TossDecision                                                 field
# SuperOver                                                        N
# WinningTeam                                       Rajasthan Royals
# WonBy                                                      Wickets
# Margin                                                         7.0
# method                                                          No
# Player_of_Match                                         JC Buttler
# Team1Players     ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# Team2Players     ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# Umpire1                                                CB Gaffaney
# Umpire2                                                Nitin Menon
# team2_runs                                                     161
# team1_runs                                                     157
#
#                                                                  2  \
# ID                                                         1312198
# City                                                       Kolkata
# Date                                                    2022-05-25
# Season                                                        2022
# MatchNumber                                                     KO
# Team1                                  Royal Challengers Bangalore
# Team2                                         Lucknow Super Giants
# Venue                                        Eden Gardens, Kolkata
# TossWinner                                    Lucknow Super Giants
# TossDecision                                                 field
# SuperOver                                                        N
# WinningTeam                            Royal Challengers Bangalore
# WonBy                                                         Runs
# Margin                                                        14.0
# method                                                          No
# Player_of_Match                                         RM Patidar
# Team1Players     ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# Team2Players     ['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda...
# Umpire1                                              J Madanagopal
# Umpire2                                                   MA Gough
# team2_runs                                                     193
# team1_runs                                                     207
#
#                                                                  3  \
# ID                                                         1312197
# City                                                       Kolkata
# Date                                                    2022-05-24
# Season                                                        2022
# MatchNumber                                                     KO
# Team1                                             Rajasthan Royals
# Team2                                               Gujarat Titans
# Venue                                        Eden Gardens, Kolkata
# TossWinner                                          Gujarat Titans
# TossDecision                                                 field
# SuperOver                                                        N
# WinningTeam                                         Gujarat Titans
# WonBy                                                      Wickets
# Margin                                                         7.0
# method                                                          No
# Player_of_Match                                          DA Miller
# Team1Players     ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# Team2Players     ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...
# Umpire1                                               BNJ Oxenford
# Umpire2                                                  VK Sharma
# team2_runs                                                     191
# team1_runs                                                     188
#
#                                                                  4
# ID                                                         1304116
# City                                                        Mumbai
# Date                                                    2022-05-22
# Season                                                        2022
# MatchNumber                                                     NO
# Team1                                          Sunrisers Hyderabad
# Team2                                                 Punjab Kings
# Venue                                     Wankhede Stadium, Mumbai
# TossWinner                                     Sunrisers Hyderabad
# TossDecision                                                   bat
# SuperOver                                                        N
# WinningTeam                                           Punjab Kings
# WonBy                                                      Wickets
# Margin                                                         5.0
# method                                                          No
# Player_of_Match                                      Harpreet Brar
# Team1Players     ['PK Garg', 'Abhishek Sharma', 'RA Tripathi', ...
# Team2Players     ['JM Bairstow', 'S Dhawan', 'M Shahrukh Khan',...
# Umpire1                                               AK Chaudhary
# Umpire2                                              NA Patwardhan
# team2_runs                                                     160
# team1_runs                                                     157

# %%
deliveries.head(5).T
# Out:
#                                   0                 1                 2  \
# ID                          1312200           1312200           1312200
# innings                           1                 1                 1
# overs                             0                 0                 0
# ballnumber                        1                 2                 3
# batter                  YBK Jaiswal       YBK Jaiswal        JC Buttler
# bowler               Mohammed Shami    Mohammed Shami    Mohammed Shami
# non-striker              JC Buttler        JC Buttler       YBK Jaiswal
# extra_type                      NaN           legbyes               NaN
# batsman_run                       0                 0                 1
# extras_run                        0                 1                 0
# total_run                         0                 1                 1
# non_boundary                      0                 0                 0
# isWicketDelivery                  0                 0                 0
# player_out                      NaN               NaN               NaN
# kind                            NaN               NaN               NaN
# fielders_involved               NaN               NaN               NaN
# BattingTeam        Rajasthan Royals  Rajasthan Royals  Rajasthan Royals
#
#                                   3                 4
# ID                          1312200           1312200
# innings                           1                 1
# overs                             0                 0
# ballnumber                        4                 5
# batter                  YBK Jaiswal       YBK Jaiswal
# bowler               Mohammed Shami    Mohammed Shami
# non-striker              JC Buttler        JC Buttler
# extra_type                      NaN               NaN
# batsman_run                       0                 0
# extras_run                        0                 0
# total_run                         0                 0
# non_boundary                      0                 0
# isWicketDelivery                  0                 0
# player_out                      NaN               NaN
# kind                            NaN               NaN
# fielders_involved               NaN               NaN
# BattingTeam        Rajasthan Royals  Rajasthan Royals

# %%
filtered_matches=matches[['ID','City','WinningTeam','team2_runs','team1_runs','Margin','MatchNumber','TossWinner','TossDecision','SuperOver','WonBy','method','Player_of_Match','Team2']]

# %%
deliveries=deliveries[deliveries['innings']==2]
deliveries.shape
# Out:
# (101740, 17)

# %%
df= filtered_matches.merge(deliveries,on='ID')
df.head(5).T
# Out:
#                                   0                 1                 2  \
# ID                          1312200           1312200           1312200
# City                      Ahmedabad         Ahmedabad         Ahmedabad
# WinningTeam          Gujarat Titans    Gujarat Titans    Gujarat Titans
# team2_runs                      133               133               133
# team1_runs                      130               130               130
# Margin                          7.0               7.0               7.0
# MatchNumber                      KO                KO                KO
# TossWinner         Rajasthan Royals  Rajasthan Royals  Rajasthan Royals
# TossDecision                    bat               bat               bat
# SuperOver                         N                 N                 N
# WonBy                       Wickets           Wickets           Wickets
# method                           No                No                No
# Player_of_Match           HH Pandya         HH Pandya         HH Pandya
# Team2                Gujarat Titans    Gujarat Titans    Gujarat Titans
# innings                           2                 2                 2
# overs                             0                 0                 0
# ballnumber                        1                 2                 3
# batter                      WP Saha           WP Saha           WP Saha
# bowler                     TA Boult          TA Boult          TA Boult
# non-striker            Shubman Gill      Shubman Gill      Shubman Gill
# extra_type                      NaN               NaN               NaN
# batsman_run                       0                 0                 1
# extras_run                        0                 0                 0
# total_run                         0                 0                 1
# non_boundary                      0                 0                 0
# isWicketDelivery                  0                 0                 0
# player_out                      NaN               NaN               NaN
# kind                            NaN               NaN               NaN
# fielders_involved               NaN               NaN               NaN
# BattingTeam          Gujarat Titans    Gujarat Titans    Gujarat Titans
#
#                                   3                 4
# ID                          1312200           1312200
# City                      Ahmedabad         Ahmedabad
# WinningTeam          Gujarat Titans    Gujarat Titans
# team2_runs                      133               133
# team1_runs                      130               130
# Margin                          7.0               7.0
# MatchNumber                      KO                KO
# TossWinner         Rajasthan Royals  Rajasthan Royals
# TossDecision                    bat               bat
# SuperOver                         N                 N
# WonBy                       Wickets           Wickets
# method                           No                No
# Player_of_Match           HH Pandya         HH Pandya
# Team2                Gujarat Titans    Gujarat Titans
# innings                           2                 2
# overs                             0                 0
# ballnumber                        4                 5
# batter                 Shubman Gill      Shubman Gill
# bowler                     TA Boult          TA Boult
# non-striker                 WP Saha           WP Saha
# extra_type                      NaN               NaN
# batsman_run                       0                 0
# extras_run                        0                 0
# total_run                         0                 0
# non_boundary                      0                 0
# isWicketDelivery                  0                 0
# player_out                      NaN               NaN
# kind                            NaN               NaN
# fielders_involved               NaN               NaN
# BattingTeam          Gujarat Titans    Gujarat Titans

# %%
df.fillna('No',inplace=True)

# %%
df.dtypes
# Out:
# ID                     int64
# City                  object
# WinningTeam           object
# team2_runs             int64
# team1_runs             int64
# Margin               float64
# MatchNumber           object
# TossWinner            object
# TossDecision          object
# SuperOver             object
# WonBy                 object
# method                object
# Player_of_Match       object
# Team2                 object
# innings                int64
# overs                  int64
# ballnumber             int64
# batter                object
# bowler                object
# non-striker           object
# extra_type            object
# batsman_run            int64
# extras_run             int64
# total_run              int64
# non_boundary           int64
# isWicketDelivery       int64
# player_out            object
# kind                  object
# fielders_involved     object
# BattingTeam           object
# dtype: object

# %%
df['current score'] = df.groupby('ID')['total_run'].cumsum()

# %%
df['runs_left']=df['team1_runs']-df['current score']

# %%
df['balls_left']= 120-(df['overs']*6+df['ballnumber'])

# %%
df = df[df['method'] == 'No']
df.drop('method',axis=1,inplace=True)

# %%
df['wickets'] = df.groupby('ID')['isWicketDelivery'].cumsum()
df['wickets_left']=10-df['wickets']

# %%
df.drop('wickets',axis=1,inplace=True)

# %%
df= df[df['balls_left']>0]
df= df[df['runs_left']>0]

# %%
df.shape
# Out:
# (93997, 33)

# %%
df=df[df['SuperOver']!='Y']
df.shape
# Out:
# (92402, 33)

# %%
df['crr']=df['current score']/((120-df['balls_left'])/6)

# %%
df['rrr']=df['runs_left']/(df['balls_left']/6)

# %%
def result(row):
    return 1 if row['BattingTeam']==row['WinningTeam'] else 0

# %%
df['results']= df.apply(result,axis=1)
df.tail().T
# Out:
#                                          95942                        95943  \
# ID                                      335982                       335982
# City                                 Bangalore                    Bangalore
# WinningTeam              Kolkata Knight Riders        Kolkata Knight Riders
# team2_runs                                  82                           82
# team1_runs                                 222                          222
# Margin                                   140.0                        140.0
# MatchNumber                                 NO                           NO
# TossWinner         Royal Challengers Bangalore  Royal Challengers Bangalore
# TossDecision                             field                        field
# SuperOver                                    N                            N
# WonBy                                     Runs                         Runs
# Player_of_Match                    BB McCullum                  BB McCullum
# Team2                    Kolkata Knight Riders        Kolkata Knight Riders
# innings                                      2                            2
# overs                                       14                           14
# ballnumber                                   5                            6
# batter                                 P Kumar                     SB Joshi
# bowler                                I Sharma                     I Sharma
# non-striker                           SB Joshi                      P Kumar
# extra_type                             legbyes                           No
# batsman_run                                  0                            1
# extras_run                                   1                            0
# total_run                                    1                            1
# non_boundary                                 0                            0
# isWicketDelivery                             0                            0
# player_out                                  No                           No
# kind                                        No                           No
# fielders_involved                           No                           No
# BattingTeam        Royal Challengers Bangalore  Royal Challengers Bangalore
# current score                               80                           81
# runs_left                                  142                          141
# balls_left                                  31                           30
# wickets_left                                 1                            1
# crr                                   5.393258                          5.4
# rrr                                  27.483871                         28.2
# results                                      0                            0
#
#                                          95944                        95945  \
# ID                                      335982                       335982
# City                                 Bangalore                    Bangalore
# WinningTeam              Kolkata Knight Riders        Kolkata Knight Riders
# team2_runs                                  82                           82
# team1_runs                                 222                          222
# Margin                                   140.0                        140.0
# MatchNumber                                 NO                           NO
# TossWinner         Royal Challengers Bangalore  Royal Challengers Bangalore
# TossDecision                             field                        field
# SuperOver                                    N                            N
# WonBy                                     Runs                         Runs
# Player_of_Match                    BB McCullum                  BB McCullum
# Team2                    Kolkata Knight Riders        Kolkata Knight Riders
# innings                                      2                            2
# overs                                       14                           15
# ballnumber                                   7                            1
# batter                                 P Kumar                     SB Joshi
# bowler                                I Sharma                    LR Shukla
# non-striker                           SB Joshi                      P Kumar
# extra_type                                  No                        wides
# batsman_run                                  0                            0
# extras_run                                   0                            1
# total_run                                    0                            1
# non_boundary                                 0                            0
# isWicketDelivery                             0                            0
# player_out                                  No                           No
# kind                                        No                           No
# fielders_involved                           No                           No
# BattingTeam        Royal Challengers Bangalore  Royal Challengers Bangalore
# current score                               81                           82
# runs_left                                  141                          140
# balls_left                                  29                           29
# wickets_left                                 1                            1
# crr                                   5.340659                     5.406593
# rrr                                  29.172414                    28.965517
# results                                      0                            0
#
#                                          95946
# ID                                      335982
# City                                 Bangalore
# WinningTeam              Kolkata Knight Riders
# team2_runs                                  82
# team1_runs                                 222
# Margin                                   140.0
# MatchNumber                                 NO
# TossWinner         Royal Challengers Bangalore
# TossDecision                             field
# SuperOver                                    N
# WonBy                                     Runs
# Player_of_Match                    BB McCullum
# Team2                    Kolkata Knight Riders
# innings                                      2
# overs                                       15
# ballnumber                                   2
# batter                                SB Joshi
# bowler                               LR Shukla
# non-striker                            P Kumar
# extra_type                                  No
# batsman_run                                  0
# extras_run                                   0
# total_run                                    0
# non_boundary                                 0
# isWicketDelivery                             1
# player_out                            SB Joshi
# kind                                    caught
# fielders_involved                  BB McCullum
# BattingTeam        Royal Challengers Bangalore
# current score                               82
# runs_left                                  140
# balls_left                                  28
# wickets_left                                 0
# crr                                   5.347826
# rrr                                       30.0
# results                                      0

# %%
fdf = df[['BattingTeam','Team2','City','runs_left','balls_left','wickets_left','crr','rrr','team1_runs','results']]
fdf
# Out:
#                        BattingTeam                  Team2       City  \
# 0                   Gujarat Titans         Gujarat Titans  Ahmedabad
# 1                   Gujarat Titans         Gujarat Titans  Ahmedabad
# 2                   Gujarat Titans         Gujarat Titans  Ahmedabad
# 3                   Gujarat Titans         Gujarat Titans  Ahmedabad
# 4                   Gujarat Titans         Gujarat Titans  Ahmedabad
# ...                            ...                    ...        ...
# 95942  Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 95943  Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 95944  Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 95945  Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 95946  Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
#
#        runs_left  balls_left  wickets_left       crr        rrr  team1_runs  \
# 0            130         119            10  0.000000   6.554622         130
# 1            130         118            10  0.000000   6.610169         130
# 2            129         117            10  2.000000   6.615385         130
# 3            129         116            10  1.500000   6.672414         130
# 4            129         115            10  1.200000   6.730435         130
# ...          ...         ...           ...       ...        ...         ...
# 95942        142          31             1  5.393258  27.483871         222
# 95943        141          30             1  5.400000  28.200000         222
# 95944        141          29             1  5.340659  29.172414         222
# 95945        140          29             1  5.406593  28.965517         222
# 95946        140          28             0  5.347826  30.000000         222
#
#        results
# 0            1
# 1            1
# 2            1
# 3            1
# 4            1
# ...        ...
# 95942        0
# 95943        0
# 95944        0
# 95945        0
# 95946        0
#
# [92402 rows x 10 columns]

# %%
fdf=fdf.sample(fdf.shape[0])

# %%
fdf
# Out:
#                        BattingTeam                Team2       City  runs_left  \
# 8263                Gujarat Titans       Gujarat Titans     Mumbai        111
# 92641             Rajasthan Royals  Sunrisers Hyderabad     Jaipur         38
# 84796  Royal Challengers Bangalore  Chennai Super Kings     Durban         93
# 48894               Delhi Capitals       Delhi Capitals       Pune         96
# 84877          Sunrisers Hyderabad       Delhi Capitals     Durban        172
# ...                            ...                  ...        ...        ...
# 49688                 Punjab Kings     Rajasthan Royals       Pune        148
# 77835                 Punjab Kings         Punjab Kings      Delhi         54
# 80205          Chennai Super Kings  Chennai Super Kings  Ahmedabad         88
# 72990          Chennai Super Kings     Rajasthan Royals    Chennai         22
# 11309               Mumbai Indians       Mumbai Indians      Dubai         62
#
#        balls_left  wickets_left       crr        rrr  team1_runs  results
# 8263           76             8  6.409091   8.763158         158        1
# 92641          47            10  8.383562   4.851064         140        1
# 84796          81             7  5.538462   6.888889         129        1
# 48894          60             8  6.900000   9.600000         165        0
# 84877         119            10  6.000000   8.672269         173        0
# ...           ...           ...       ...        ...         ...      ...
# 49688         110             9  8.400000   8.072727         162        0
# 77835          61             9  5.796610   5.311475         111        0
# 80205          49             7  7.521127  10.775510         177        0
# 72990          24             9  7.812500   5.500000         147        1
# 11309          26             5  6.574468  14.307692         165        0
#
# [92402 rows x 10 columns]

# %%
fdf.describe()
# Out:
#           runs_left    balls_left  wickets_left           crr           rrr  \
# count  92402.000000  92402.000000  92402.000000  92402.000000  92402.000000
# mean      93.138590     63.199130      7.563570      7.402961     10.605363
# std       49.310641     33.051431      2.137717      2.241167     13.003608
# min        1.000000      1.000000      0.000000      0.000000      0.083333
# 25%       54.000000     35.000000      6.000000      6.255319      7.161290
# 50%       92.000000     64.000000      8.000000      7.466667      8.869565
# 75%      130.000000     92.000000      9.000000      8.640000     10.947368
# max      246.000000    119.000000     10.000000     36.000000    708.000000
#
#          team1_runs       results
# count  92402.000000  92402.000000
# mean     165.473918      0.424677
# std       28.849578      0.494297
# min       67.000000      0.000000
# 25%      147.000000      0.000000
# 50%      165.000000      0.000000
# 75%      185.000000      1.000000
# max      246.000000      1.000000

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
transformer= ColumnTransformer([('cat', OneHotEncoder(drop='first'),['BattingTeam','Team2','City'])],remainder="passthrough")

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(fdf.drop('results',axis=1),fdf['results'],test_size=0.2)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.pipeline import Pipeline

# %%
pipeline = Pipeline([
    ('transformer', transformer),
    ('model', LogisticRegression(solver='liblinear'))])
pipeline.fit(X_train,y_train)
pred=pipeline.predict(X_test)
accuracy_score(y_test,pred)
# Out:
# 0.8171094637736053

# %%
pipeline.predict_proba(X_test.sample())
# Out:
# array([[0.93353061, 0.06646939]])

# %%
df.head().T
# Out:
#                                   0                 1                 2  \
# ID                          1312200           1312200           1312200
# City                      Ahmedabad         Ahmedabad         Ahmedabad
# WinningTeam          Gujarat Titans    Gujarat Titans    Gujarat Titans
# team2_runs                      133               133               133
# team1_runs                      130               130               130
# Margin                          7.0               7.0               7.0
# MatchNumber                      KO                KO                KO
# TossWinner         Rajasthan Royals  Rajasthan Royals  Rajasthan Royals
# TossDecision                    bat               bat               bat
# SuperOver                         N                 N                 N
# WonBy                       Wickets           Wickets           Wickets
# Player_of_Match           HH Pandya         HH Pandya         HH Pandya
# Team2                Gujarat Titans    Gujarat Titans    Gujarat Titans
# innings                           2                 2                 2
# overs                             0                 0                 0
# ballnumber                        1                 2                 3
# batter                      WP Saha           WP Saha           WP Saha
# bowler                     TA Boult          TA Boult          TA Boult
# non-striker            Shubman Gill      Shubman Gill      Shubman Gill
# extra_type                       No                No                No
# batsman_run                       0                 0                 1
# extras_run                        0                 0                 0
# total_run                         0                 0                 1
# non_boundary                      0                 0                 0
# isWicketDelivery                  0                 0                 0
# player_out                       No                No                No
# kind                             No                No                No
# fielders_involved                No                No                No
# BattingTeam          Gujarat Titans    Gujarat Titans    Gujarat Titans
# current score                     0                 0                 1
# runs_left                       130               130               129
# balls_left                      119               118               117
# wickets_left                     10                10                10
# crr                             0.0               0.0               2.0
# rrr                        6.554622          6.610169          6.615385
# results                           1                 1                 1
#
#                                   3                 4
# ID                          1312200           1312200
# City                      Ahmedabad         Ahmedabad
# WinningTeam          Gujarat Titans    Gujarat Titans
# team2_runs                      133               133
# team1_runs                      130               130
# Margin                          7.0               7.0
# MatchNumber                      KO                KO
# TossWinner         Rajasthan Royals  Rajasthan Royals
# TossDecision                    bat               bat
# SuperOver                         N                 N
# WonBy                       Wickets           Wickets
# Player_of_Match           HH Pandya         HH Pandya
# Team2                Gujarat Titans    Gujarat Titans
# innings                           2                 2
# overs                             0                 0
# ballnumber                        4                 5
# batter                 Shubman Gill      Shubman Gill
# bowler                     TA Boult          TA Boult
# non-striker                 WP Saha           WP Saha
# extra_type                       No                No
# batsman_run                       0                 0
# extras_run                        0                 0
# total_run                         0                 0
# non_boundary                      0                 0
# isWicketDelivery                  0                 0
# player_out                       No                No
# kind                             No                No
# fielders_involved                No                No
# BattingTeam          Gujarat Titans    Gujarat Titans
# current score                     1                 1
# runs_left                       129               129
# balls_left                      116               115
# wickets_left                     10                10
# crr                             1.5               1.2
# rrr                        6.672414          6.730435
# results                           1                 1

# %%
def match_progression(x_df,match_id,pipe):
    match = x_df[x_df['ID'] == match_id]# Collecting all data of 1 Match
    match = match[(match['ballnumber'] == 6)]# Filtering onlt the 6th ball
    temp_df = match[['BattingTeam','Team2','City','runs_left','balls_left','wickets_left','crr','rrr','team1_runs']]# Final df with selected columns
    result = pipeline.predict_proba(temp_df)
    temp_df['lose'] = np.round(result.T[0]*100,2)#loose percentage
    temp_df['win'] = np.round(result.T[1]*100,2)#win percentage
    temp_df['end_of_over'] = range(1,temp_df.shape[0]+1)
    
    target = temp_df['team1_runs'].values[0]# getting target value
    temp_df['current_score']= target-temp_df['runs_left']
    runs = list(temp_df['runs_left'].values)
    new_runs = runs[:]
    runs.insert(0,target)
    temp_df['runs_after_over'] = np.array(runs)[:-1] - np.array(new_runs)
    wickets = list(temp_df['wickets_left'].values)
    new_wickets = wickets[:]
    new_wickets.insert(0,10)
    wickets.append(0)
    w = np.array(wickets)
    nw = np.array(new_wickets)
    temp_df['wickets_in_over'] = (nw - w)[0:temp_df.shape[0]]
    
    print("Target-",target)
    temp_df = temp_df[['end_of_over','runs_after_over','wickets_in_over','lose','win','current_score','rrr','crr']]
    return temp_df,target

# %%
pd.options.mode.chained_assignment = None

# %%
temp_df,target = match_progression(df,335990,pipeline)
temp_df
# Out:
# Target- 214
#        end_of_over  runs_after_over  wickets_in_over   lose    win  \
# 94933            1                5                0  85.75  14.25
# 94939            2                9                0  83.21  16.79
# 94945            3                5                1  89.28  10.72
# 94951            4               12                0  85.96  14.04
# 94958            5               26                0  71.07  28.93
# 94964            6               16                0  60.01  39.99
# 94970            7                9                0  55.46  44.54
# 94976            8               16                0  42.78  57.22
# 94982            9               12                0  34.84  65.16
# 94988           10                4                1  49.00  51.00
# 94994           11                7                0  47.03  52.97
# 95000           12                5                1  61.32  38.68
# 95006           13                8                0  59.17  40.83
# 95012           14                5                0  62.21  37.79
# 95018           15               20                0  41.78  58.22
# 95024           16               17                0  25.48  74.52
# 95030           17               10                0  20.73  79.27
# 95036           18                2                2  61.32  38.68
# 95043           19                9                2  89.32  10.68
#
#        current_score        rrr        crr
# 94933              5  11.000000   5.000000
# 94939             14  11.111111   7.000000
# 94945             19  11.470588   6.333333
# 94951             31  11.437500   7.750000
# 94958             57  10.466667  11.400000
# 94964             73  10.071429  12.166667
# 94970             82  10.153846  11.714286
# 94976             98   9.666667  12.250000
# 94982            110   9.454545  12.222222
# 94988            114  10.000000  11.400000
# 94994            121  10.333333  11.000000
# 95000            126  11.000000  10.500000
# 95006            134  11.428571  10.307692
# 95012            139  12.500000   9.928571
# 95018            159  11.000000  10.600000
# 95024            176   9.500000  11.000000
# 95030            186   9.333333  10.941176
# 95036            188  13.000000  10.444444
# 95043            197  17.000000  10.368421

# %%
import matplotlib.pyplot as plt

# Assuming temp_df is your DataFrame containing the data

# Your existing code
plt.figure(figsize=(18, 8))
plt.plot(temp_df['end_of_over'], temp_df['win'], color='#00a65a', linewidth=4, label='Win')
plt.plot(temp_df['end_of_over'], temp_df['lose'], color='red', linewidth=4, label='Lose')

# Plotting runs_after_over as a bar plot
plt.bar(temp_df['end_of_over'], temp_df['runs_after_over'], color='blue', alpha=0.5, label='Runs after Over')

# Plotting yellow dots for wickets_in_over
for index, row in temp_df.iterrows():
    wickets = int(row['wickets_in_over'])  # Convert to integer
    end_of_over = row['end_of_over']
    plt.scatter([end_of_over] * wickets, [row['runs_after_over']] * wickets, color='yellow', s=100, zorder=5)

# Set x-axis scale from 1 to 20
plt.xticks(range(1, 21))

# Adding labels and title
plt.title('Target - ' + str(target))
plt.xlabel('End of Over')
plt.ylabel('Runs After Over')
plt.legend()
plt.show()

# %%
teams
# Out:
# ['Rajasthan Royals',
#  'Royal Challengers Bangalore',
#  'Sunrisers Hyderabad',
#  'Delhi Capitals',
#  'Chennai Super Kings',
#  'Gujarat Titans',
#  'Lucknow Super Giants',
#  'Kolkata Knight Riders',
#  'Punjab Kings',
#  'Mumbai Indians']

# %%
cities= df['City'].unique().tolist()
cities
# Out:
# ['Ahmedabad',
#  'Kolkata',
#  'Mumbai',
#  'Navi Mumbai',
#  'Pune',
#  'Dubai',
#  'Sharjah',
#  'Abu Dhabi',
#  'Delhi',
#  'Chennai',
#  'Hyderabad',
#  'Visakhapatnam',
#  'Chandigarh',
#  'Bengaluru',
#  'Jaipur',
#  'Indore',
#  'Bangalore',
#  'Raipur',
#  'Ranchi',
#  'Cuttack',
#  'Dharamsala',
#  'Nagpur',
#  'Johannesburg',
#  'Centurion',
#  'Durban',
#  'Bloemfontein',
#  'Port Elizabeth',
#  'Kimberley',
#  'East London',
#  'Cape Town']

# %%
import pickle
pickle.dump(pipeline,open('pipeline.pkl','wb'))

# %%
import joblib
joblib.dump(pipeline, 'my_pipeline.joblib')
loaded_pipeline = joblib.load('my_pipeline.joblib')
