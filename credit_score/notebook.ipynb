# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly

# %%
df=pd.read_csv('/workspaces/projects/Credit Score Classification/final.csv')

# %%
df.drop(['Home Equity Loan','Auto Loan','Mortgage Loan','Payday Loan','Student Loan','Debt Consolidation Loan','Personal Loan','Credit-Builder Loan'],axis=1,inplace=True)

# %%
df.drop(['Credit_Mix','Payment_of_Min_Amount','Credit_History_Age','Num_Credit_Inquiries','Changed_Credit_Limit','Delay_from_due_date','Num_Bank_Accounts','Annual_Income','Monthly_Balance'],axis=1,inplace=True)

# %%
df.head().T
# Out:
#                                                         0  \
# Age                                                  23.0
# Occupation                                      Scientist
# Monthly_Inhand_Salary                         1824.843333
# Num_Credit_Card                                       4.0
# Interest_Rate                                         3.0
# Num_of_Loan                                           4.0
# Num_of_Delayed_Payment                                7.0
# Outstanding_Debt                                   809.98
# Credit_Utilization_Ratio                         26.82262
# Total_EMI_per_month                             49.574949
# Amount_invested_monthly                         80.415295
# Payment_Behaviour         High_spent_Small_value_payments
# Credit_Score                                         Good
#
#                                                        1  \
# Age                                                 23.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28900 entries, 0 to 28899
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       28900 non-null  float64
#  1   Occupation                28900 non-null  object
#  2   Monthly_Inhand_Salary     28900 non-null  float64
#  3   Num_Credit_Card           28900 non-null  float64
#  4   Interest_Rate             28900 non-null  float64
#  5   Num_of_Loan               28900 non-null  float64
#  6   Num_of_Delayed_Payment    28899 non-null  float64
#  7   Outstanding_Debt          28899 non-null  float64
#  8   Credit_Utilization_Ratio  28899 non-null  float64
#  9   Total_EMI_per_month       28899 non-null  float64
#  10  Amount_invested_monthly   28899 non-null  float64
#  11  Payment_Behaviour         28899 non-null  object
#  12  Credit_Score              28899 non-null  object
# dtypes: float64(10), object(3)
# ...

# %%
df= df[df['Payment_Behaviour'].notna()]

# %%
df.head()
# Out:
#     Age Occupation  Monthly_Inhand_Salary  Num_Credit_Card  Interest_Rate  \
# 0  23.0  Scientist            1824.843333              4.0            3.0
# 1  23.0  Scientist            1824.843333              4.0            3.0
# 2  33.0  Scientist            1824.843333              4.0            3.0
# 3  23.0  Scientist            1824.843333              4.0            3.0
# 4  23.0  Scientist            1824.843333              4.0            3.0
#
#    Num_of_Loan  Num_of_Delayed_Payment  Outstanding_Debt  \
# 0          4.0                     7.0            809.98
# 1          4.0                     7.0            809.98
# 2          4.0                     7.0            809.98
# 3          4.0                     4.0            809.98
# 4          4.0                     7.0            809.98
#
#    Credit_Utilization_Ratio  Total_EMI_per_month  Amount_invested_monthly  \
# 0                 26.822620            49.574949                80.415295
# ...

# %%
df.describe()
# Out:
#                 Age  Monthly_Inhand_Salary  Num_Credit_Card  Interest_Rate  \
# count  28899.000000           28899.000000     28899.000000   28899.000000
# mean      33.236617            4040.410318         5.518011      14.333333
# std       10.519962            2902.780121         2.032075       8.673247
# min       14.000000             333.596667         0.000000       1.000000
# 25%       25.000000            1650.781667         4.000000       7.000000
# 50%       33.000000            3096.836667         5.000000      13.000000
# 75%       41.000000            5872.071667         7.000000      20.000000
# max       56.000000           12446.180000        11.000000      34.000000
#
#         Num_of_Loan  Num_of_Delayed_Payment  Outstanding_Debt  \
# count  28899.000000            28899.000000      28899.000000
# mean       3.520606               13.268348       1220.829288
# std        2.383927                6.311986        889.710057
# ...

# %%
df['Num_of_Delayed_Payment'] = df['Num_of_Delayed_Payment'].apply(lambda x: max(0, x))

# %%
df.describe()
# Out:
#                 Age  Monthly_Inhand_Salary  Num_Credit_Card  Interest_Rate  \
# count  28899.000000           28899.000000     28899.000000   28899.000000
# mean      33.236617            4040.410318         5.518011      14.333333
# std       10.519962            2902.780121         2.032075       8.673247
# min       14.000000             333.596667         0.000000       1.000000
# 25%       25.000000            1650.781667         4.000000       7.000000
# 50%       33.000000            3096.836667         5.000000      13.000000
# 75%       41.000000            5872.071667         7.000000      20.000000
# max       56.000000           12446.180000        11.000000      34.000000
#
#         Num_of_Loan  Num_of_Delayed_Payment  Outstanding_Debt  \
# count  28899.000000            28899.000000      28899.000000
# mean       3.520606               13.279421       1220.829288
# std        2.383927                6.286950        889.710057
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 28899 entries, 0 to 28898
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       28899 non-null  float64
#  1   Occupation                28899 non-null  object
#  2   Monthly_Inhand_Salary     28899 non-null  float64
#  3   Num_Credit_Card           28899 non-null  float64
#  4   Interest_Rate             28899 non-null  float64
#  5   Num_of_Loan               28899 non-null  float64
#  6   Num_of_Delayed_Payment    28899 non-null  float64
#  7   Outstanding_Debt          28899 non-null  float64
#  8   Credit_Utilization_Ratio  28899 non-null  float64
#  9   Total_EMI_per_month       28899 non-null  float64
#  10  Amount_invested_monthly   28899 non-null  float64
#  11  Payment_Behaviour         28899 non-null  object
#  12  Credit_Score              28899 non-null  object
# dtypes: float64(10), object(3)
# ...

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
transformer= ColumnTransformer([('cat', OneHotEncoder(drop='first'),['Occupation','Payment_Behaviour'])],remainder="passthrough")

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(df.drop('Credit_Score',axis=1),df['Credit_Score'],test_size=0.2)

# %%
pip install xgboost
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

# %%
pipeline = Pipeline([
    ('transformer', transformer),
    ('model', RandomForestClassifier())])
pipeline.fit(X_train,y_train)
pred=pipeline.predict(X_test)
accuracy_score(y_test,pred)
# Out:
# 0.7865051903114186

# %%
import joblib
joblib.dump(pipeline, 'pipeline.joblib')
loaded_pipeline = joblib.load('pipeline.joblib')

# %%
occupations = df['Occupation'].unique().tolist()

# %%
occupations
# Out:
# ['Scientist',
#  'Teacher',
#  'Engineer',
#  'Entrepreneur',
#  'Developer',
#  'Lawyer',
#  'Media_Manager',
#  'Doctor',
#  'Journalist',
#  'Manager',
#  'Accountant',
#  'Musician',
#  'Mechanic',
#  'Writer',
#  'Architect']

# %%
behaviour=df['Payment_Behaviour'].unique().tolist()
behaviour
# Out:
# ['High_spent_Small_value_payments',
#  'Low_spent_Large_value_payments',
#  'Low_spent_Medium_value_payments',
#  'Low_spent_Small_value_payments',
#  'High_spent_Medium_value_payments',
#  'High_spent_Large_value_payments']

# %%
category =df['Credit_Score'].unique().tolist()
category
# Out:
# ['Good', 'Standard', 'Poor']

# %%
pip install streamlit
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
